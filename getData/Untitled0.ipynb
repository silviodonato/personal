# %%
### Define the HTML parser class. We use it to simply transform the html in a string without tags (MyHTMLParser.text)
import urllib2
from HTMLParser import HTMLParser
class MyHTMLParser(HTMLParser):
    HTMLParser.text = ""
    HTMLParser.currentTags = []
    def handle_starttag(self, tag, attrs):
        self.currentTags.append(tag)
#        print "Encountered a start tag:", tag

    def handle_endtag(self, tag):
        el = self.currentTags.pop()
        if el!=tag:
            Exception("parsing error. El = %s, Tag = %s"%(el,tag))
#        print "Encountered an end tag :", tag

    def handle_data(self, data):
        if len(self.currentTags)>0 and self.currentTags[-1] == "code":
            self.text +="["+data+"]"
        else:
            self.text +=data
#        print data,
#        print "Encountered some data  :", data,self.currentTags

# %%
response = urllib2.urlopen('http://www.gazzetta.it/speciali/risultati_classifiche/2010/calcio/seriea/calendario.shtml')

# %%
mfile = response.read()
parser = MyHTMLParser()
parser.feed(mfile)

# %%
print parser.text
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# var perPath = '/ssi/2008/boxes/calcio/calendari/calendario_';
# var postPath = '.shtml';
# function stampaCal(url){
# 	url = url.replace('estero-','');
# 	window.open(perPath+url+postPath, "calWind",
# 	"toolbar=no,left=1,top=1,height=700,directories=no,location=no,status=no,statusbar=no,resizable=1,menubar=no,scrollbars=yes");
# }
#
#
#
#
#
#
#
#
# 		//variabile utilizzata nel meteo.js
# 		var pathImgMeteo = 'http://images2.gazzettaobjects.it/libs4/css/assets';
# 		//utilizzata per il menu di sportweek
# 		var selected = 'risultati';
#
# 		//ADV function
# 			function getSite() {
# 				return "gazzetta";
# 			};
#
# 		var temporeale_xml = "(none)";
#
# 		//CONTROLLO USERAGENT IPAD PER GESTIRE GLI ELEMENTI NON GESTITI
# 		var browser_user_ag = "";
# 		var useragent_check = navigator.userAgent;
# 		if(useragent_check.indexOf('iPad') > -1) browser_user_ag = "iPad";
#
# 		function popUpGallery_rel(url,type,strWidth,strHeight){
# 			var tools="";
# 			tools="resizable=0,toolbar=no,location=no,scrollbars=no,width="+strWidth+",height="+strHeight+",left=0,top=0";
# 			nuova_finestra=window.open(url,'fotogallery',tools);
# 			nuova_finestra.focus();
# 		}
#
# 		function openPopup_rel(element){
#
# 			var hr = $(element).attr("href");
#
# 			if(hr.indexOf("apri_popup_methode_mailto")==-1){
#
# 				if(($(element).attr("href")).indexOf("vuoto.shtml")>-1) {
# 					w = "750";
# 					h = "565";
# 				}
# 				else {
# 					if($.browser.msie && $.browser.version < 7){
# 						w = "600";
# 						h = "770";
# 					}
# 					else {
# 						w = "600";
# 						h = "750";
# 					}
# 				}
# 				popUpGallery_rel($(element).attr("href"),t,w,h);
# 			}
# 			return false;
# 		}
#
# 		Date.monthNames = ['mese','Gen', 'Feb', 'Mar', 'Apr', 'Mag', 'Giu', 'Lug', 'Ago', 'Set', 'Ott', 'Nov', 'Dic'];
# 		Date.dayNames = ['Dom', 'Lun', 'Mar', 'Mer', 'Gio', 'Ven', 'Sab'];
# 		Date.dayNamesLong = ['Domenica', 'Luned�', 'Marted�', 'Mercoled�', 'Gioved�', 'Venerd�', 'Sabato'];
# 		var server_date = '09-17-17-37-0-38-22-2017-16';
# 		var server_date_split = server_date.split('-');
#
# 		//MESE
# 		var server_m = (server_date_split[0]/1);
# 		var server_m_mm = server_date_split[0];
# 		//MESE TESTO
# 		var server_m_text = Date.monthNames[server_m];
#
# 		//GIORNO
# 		var server_d = (server_date_split[1]/1);
# 		var server_d_dd = server_date_split[1];
# 		//GIORNO TESTO
# 		var server_day_t = Date.dayNames[server_date_split[4]];
# 		var server_day_tt = Date.dayNamesLong[server_date_split[4]];
#
# 		//ANNO
# 		var server_y = server_date_split[2];
# 		var server_yyyy = server_date_split[7];
#
# 		//SETTIMANA
# 		var server_W = (server_date_split[3]/1)+1;
#
# 		if (server_W > 52) {
# 			var server_W = 1;
# 		}
#
# 		//NUMERO GIORNO SETTIMANA
# 		var server_day_of_week = server_date_split[4]/1;
# 		//SECONDI
# 		var server_secondi = server_date_split[8];
# 		//MINUTI
# 		var server_minute = server_date_split[5]/1;
# 		var server_minute_mm = server_date_split[5];
# 		//ORA
# 		var server_hour = server_date_split[6]/1;
# 		var server_hour_hh = server_date_split[6];
#
#
# 		function pickRandom(range) {
# 			if (Math.random) return Math.round(Math.random() * (range-1));
# 			else {
# 				var now = new Date();
# 				return (now.getTime() / 1000) % range;
# 			}
# 		}
#
#
#
#
#
#
#
#
#
#
#
#   	<!--
# 	///////////////// BT - Start /////////////////
# 	OAS_taxonomy = '';
# 	var pageUrlPath = window.location.href.replace(window.location.protocol + "//", "");
#
# 	pageUrlPath = pageUrlPath.replace(/%2F/g,"/");
#
# 	pageUrlPath = pageUrlPath.replace(/%3F/g,"/");
# 	pageUrlPath = pageUrlPath.replace(/\?/g,"/");
#
# 	pageUrlPath = pageUrlPath.replace(/%21/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/!/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%2A/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/\*/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%22/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/\"/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%27/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/'/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%28/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/\(/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%29/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/\)/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%3B/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/;/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%3A/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/\:/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%40/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/@/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%26/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/&/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%3D/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/=/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%2B/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/\+/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%24/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/\$/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%2C/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/,/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%23/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/#/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%5B/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/\[/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%5D/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/\]/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%20/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/ /g,"_");
#
# 	//Tenere la sostituzione del % come ultima istruzione
# 	pageUrlPath = pageUrlPath.replace(/%25/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/\%/g,"_");
#
# 	//
# 	// Per disabilitare BT commentare la riga sottostante
# 	//
#
#
# 	-->
#
#
#
#
#
#
# 		// definizione variabili pagina e posizioni
#
#
# 			OAS_sitepage = 'gazzetta.it/calcio';
# 			OAS_listpos = 'Top,TopLeft,Frame1,Position1';
#
#
#   //end OAS Analytics
#
#
#
#
#
#
#
# 				var CookiePolicyAccepted = false;
#
# 					var _ricIsPresent = Boolean(document.cookie.match(/(?:^|;)\s?__ric=(.*?)(?:;|$)/));
# 					var _cpmt_xaValue = document.cookie.match(/(?:^|;)\s?cpmt_xa=(.*?)(?:;|$)/);
# 					var _cpmt_xaIsPresent = Boolean(_cpmt_xaValue && (_cpmt_xaValue[1].indexOf("5295") > -1));
# 					CookiePolicyAccepted = !navigator.cookieEnabled || _ricIsPresent || _cpmt_xaIsPresent;
#
#
#                 var _scriptSrc = "http://js.gazzettaobjects.it/includes2013/LIBS/js/mjx.js";
#                 var _mockScript = "http://js.gazzettaobjects.it/includes2013/LIBS/js/MJX_OFF/mjx.js";
#
#                 if(typeof CookiePolicyAccepted == "boolean" && CookiePolicyAccepted){
#                     document.write('<scr'+'ipt type="text/javascript" src="' + _scriptSrc + '"></sc'+'ript>');
#                 } else {
#                     document.write('<scr'+'ipt type="text/javascript" src="' + _mockScript + '"></sc'+'ript>');
#                 }
#
#
#
#
#
#
#
# function createEmbed(clipId, channelId, siteId)
# {
#   //console.log("clipId:"+clipId+", channelId: "+channelId+ ", siteId: "+siteId);
#
#
# 	var clsId = "clsid:D27CDB6E-AE6D-11cf-96B8-444553540000";
# 	var cdBase = "http://fpdownload.macromedia.com/pub/shockwave/cabs/flash/swflash.cab#version=8,0,0,0";
# 	var pId = "vxFlashPlayer4139";
# 	var width = "300";
# 	var height = "250";
# 	var movieParam = "http://publish.vx.roo.com/rcsgazzetta/mini/flashembed/";
# 	var allowScriptAccessParam = "always";
# 	var allowFullscreenParam = "true";
# 	var movieQuality = "high";
# 	var wmodeParam = "windowed";
#
# 	var scaleParam = "noScale";
# 	var embedType = "application/x-shockwave-flash";
# 	var embedSrc = "http://publish.vx.roo.com/rcsgazzetta/mini/flashembed/";
#
# 	var flashvarsParam = "vxBaseURL=http%3A//publish.vx.roo.com/rcsgazzetta/mini/&vxTemplate=http%3A//publish.vx.roo.com/rcsgazzetta/mini/Gazzetta_Miniplayer_Article.swf&vxEmbedMode=fullsize&vxSiteId="+siteId+"&vxChannel="+channelId+"&vxSearch=&vxClipId="+clipId+"&vxBitrate=&vxFormat=&vxServerBase=&vxIMU=&vxClickToPlay=&vxTint=&vxFullscreen=imuCompatibility&vxSecure=false&vxBD=&vxHBX=&vxExternalIMU=&vxRowCount=&vxStartMode=normal&vxCore=&vxPreviewId=&vxDebug=&vxFilmStrip=&vxDynChannel=&vxHBXClipIdVar=&vxHBXClientType=Flash Player&vxOriginChannel=";
#
#   document.write('<object classid="'+clsId+'" codebase="'+cdBase+'" id="'+pId+'" width="'+width+'" height="'+height+'"><param name="movie" value="'+movieParam+'" /><param name="allowScriptAccess" value="'+allowScriptAccessParam+'" /><param name="allowFullscreen" value="'+allowFullscreenParam+'" /><param name="quality" value="'+movieQuality+'" /><param name="scale" value="'+scaleParam+'" /><param name="wmode" value="'+wmodeParam+'" /><param name="flashvars" value="'+flashvarsParam+'"/><embed type="'+embedType+'" src="'+embedSrc+'" width="'+width+'" height="'+height+'" allowScriptAccess="'+allowScriptAccessParam+'" allowFullscreen="'+allowFullscreenParam+'" quality="'+movieQuality+'" scale="'+scaleParam+'" wmode="'+wmodeParam+'" flashvars="'+flashvarsParam+'"></embed></object>');
# }
#
#
#
#
# var disciplinaSelected;
# var currentDateCms;
#
# function CambiaDisciplina(disciplinaSelected) {
# 	$('.disciplina .selected, .scegli_disciplina .selected').removeClass('selected');
# 	$('.disciplina #' +disciplinaSelected).addClass('selected');
# 	$('.scegli_disciplina #' +disciplinaSelected).addClass('selected');
# }
# function CambiaData(currentDateCms) {
# 	$('.date .selected').removeClass('selected');
# 	$('.date .' +currentDate).addClass('selected');
#
# }
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!--// <![CDATA[
# var OA_zones = {
# 	'GAZbac01' : 220,
# 	'GAZbac02' : 221,
# 	'GAZbac03' : 222,
# 	'GAZbac04' : 223,
# 	'GAZbac05' : 224,
# 	'GAZbac06' : 225,
# 	'GAZbac07' : 226,
# 	'GAZbac08' : 227,
# 	'GAZbac09' : 228,
# 	'GAZbac10' : 229,
# 	'1bacmkt1': 365,
# 	'1bacmkt2': 366,
# 	'1bacmkt3': 367,
# 	'1bacmkt4': 368,
# 	'consigli1' : 380,
# 	'consigli2' : 381,
# 	'consigli3' : 382,
# 	'consigli4' : 383,
# 	'consigli5' : 384,
# 	'BoxPromoCALCIOGAZ01top' : 464,
# 	'BoxPromoCALCIOGAZ02bot' : 465,
# 	'Multibarmkt1' : 639,
# 	'MultibarDiretta1' : 640,
# 	'MultibarWidgetGoal':689
#
# };
# // ]]> -->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	Risultati e Classifiche - Calcio - Serie A - La Gazzetta dello Sport
#
#
#
#
#
#
#
#
#
#
#
# <!--
# OAS_AD('Position1');
# //-->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         mobile
#         gazzatown
#         sportlinx
#         forum
#
#
#
#
#
#
#
#
#   GAZZAGAME
#   I migliori giochi online, gratis!GIOCA SUBITO
#
#
#
#
#
#
#
#
#
#
#
#
# La Gazzetta dello Sport.it
#
#
#
#                         document.write(server_day_t+" "+server_d_dd+" "+server_m_text+" "+server_yyyy+", "+server_hour_hh+":"+server_minute_mm);
#                         RSS
#                         | VEDI TUTTE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     Temperatura  | Umidit
#
#
#
#                 Cambia localit
#
#
#
#
#
#
#
#
#
#
#
# 	  Bari
#
# 		Belluno
#
# 		Bergamo
#
# 		Bologna
#
# 		Cagliari
#
# 		Catania
#
#         Catanzaro
#
# 		Firenze
#
# 		Genova
#
# 		Lecce
#
# 		Livorno
#
# 		Milano
#
# 		Napoli
#
# 		Padova
#
# 		Palermo
#
# 		Parma
#
# 		Reggio Calabria
#
# 		Roma
#
# 		Rovigo
#
# 		Siena
#
# 		Torino
#
# 		Treviso
#
# 		Udine
#
# 		Verona
#
# 		Vicenza
#
#
#
#
#
# 	Conferma cambio localit
#
#
#
#
# 	Home
# 	Calcio
# 		Calciomercato
# 	ET-Calcio estero					Motori
#
#
#
#
#
# 	Tour
# 	Basket
#
#    Tennis
# 	Altri Sport
# 	GazzettaTV
# 	Blog
# 	GazzaSpace
# 		Magic
# 			Scommesse
# 				Gazzagame
#
#
#
#
# 	Home
# 	Tempo reale
# 	Serie A
# 	Nazionale
# 	Serie B
# 	Calciomercato
# 	Calcio Estero
# 	Champions League
# 	Europa League
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   <!--
#   OAS_AD('TopLeft');
#   //-->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Registrati
#
#
# 	Cerca
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# // Settaggi per stepCarousel
# stepcarousel.setup({
# 	galleryid: 'mygallery', //id of carousel DIV
# 	containerid: 'content_menu_eng', //id che contiene il galleryid
# 	beltclass: 'belt', //class of inner "belt" DIV containing all the panel DIVs
# 	panelclass: 'panel', //class of panel DIVs each holding content
# 	autostep: {enable:false, moveby:1, pause:3000},
# 	panelbehavior: {speed:200, wraparound:false, wrapbehavior:'slide', persist:false},
# 	defaultbuttons: {enable: true, moveby: 4, leftnav: ['http://www.gazzetta.it/libs/css/default_theme/assets/cms_barMenu/sxn_arrow.png', 166, 6], rightnav: ['http://www.gazzetta.it/libs/css/default_theme/assets/cms_barMenu/dxn_arrow.png', 190, 6]},
# 	statusvars: ['statusA', 'statusB', 'statusC'], //register 3 variables that contain current panel (start), current panel (last), and total panels
# 	contenttype: ['inline'], //content setting ['inline'] or ['ajax', 'path_to_external_file']
# 	oninit:function(){
# 			var posTab = queryString("pos");
# 			if (posTab == false) {
# 				posTab = 1;
# 			}
# 			stepcarousel.stepTo("mygallery", posTab);
# 			posTab = posTab-1;
# 			$(".belt li:eq("+posTab+")").find('a').addClass('active-tab-menu');
# 			 $(".belt div:eq("+posTab+")").find('a').addClass('active-tab-menu');
#
# 		}
# })
#
#
#
# 	RISULTATI E CLASSIFICHE
#
#
#
# 			SERIE A
# 			SERIE Bwin
# 			CHAMPIONS LEAGUE
# 			EUROPA LEAGUE
# 			COPPA ITALIA
# 			LIGA
# 			LIGUE 1
# 			BUNDESLIGA
# 			PREMIER LEAGUE
# 			SERIE PRO GIRONE 1 A
# 			SERIE PRO GIRONE 1 B
# 			SERIE PRO GIRONE 2 A
# 			SERIE PRO GIRONE 2 B
# 			SERIE PRO GIRONE 2 C
# 			SERIE D
# 			SOCCER 5
# 			SERIE A FEMMINILE
# 			MLS
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     RISULTATI E CLASSIFICHE
#
#     CALENDARIO
#
#     TUTTE LE SQUADRE
#
#     ALBO D'ORO
#
#
#
#
#
#
#
#
# 			SERIE A 2009/2010 Scarica e stampa il calendario completo in formato PDF
#
#
#
#
#  1  Giornata
# Andata
# 		22,
# 		23-ago
#
# Ritorno
# 		16,17-gen
#
#
#
#
#
# 					bologna
#
#
#
#
# 					fiorentina
#
#
#
#
# 						1-1
#
#
#
#
# 						2-1
#
#
#
#
#
#
# 					siena
#
#
#
#
# 					milan
#
#
#
#
# 						1-2
#
#
#
#
# 						0-4
#
#
#
#
#
#
# 					inter
#
#
#
#
# 					bari
#
#
#
#
# 						1-1
#
#
#
#
# 						2-2
#
#
#
#
#
#
# 					catania
#
#
#
#
# 					sampdoria
#
#
#
#
# 						1-2
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					genoa
#
#
#
#
# 					roma
#
#
#
#
# 						3-2
#
#
#
#
# 						0-3
#
#
#
#
#
#
# 					juventus
#
#
#
#
# 					chievo
#
#
#
#
# 						1-0
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					lazio
#
#
#
#
# 					atalanta
#
#
#
#
# 						1-0
#
#
#
#
# 						0-3
#
#
#
#
#
#
# 					livorno
#
#
#
#
# 					cagliari
#
#
#
#
# 						0-0
#
#
#
#
# 						0-3
#
#
#
#
#
#
# 					palermo
#
#
#
#
# 					napoli
#
#
#
#
# 						2-1
#
#
#
#
# 						0-0
#
#
#
#
#
#
# 					udinese
#
#
#
#
# 					parma
#
#
#
#
# 						2-2
#
#
#
#
# 						0-0
#
#
#
#
#
#
#
#
#
#
#  2  Giornata
# Andata
# 		29,
# 		30-ago
#
# Ritorno
# 		23,24-gen
#
#
#
#
#
# 					bari
#
#
#
#
# 					bologna
#
#
#
#
# 						0-0
#
#
#
#
# 						1-2
#
#
#
#
#
#
# 					milan
#
#
#
#
# 					inter
#
#
#
#
# 						0-4
#
#
#
#
# 						0-2
#
#
#
#
#
#
# 					roma
#
#
#
#
# 					juventus
#
#
#
#
# 						1-3
#
#
#
#
# 						2-1
#
#
#
#
#
#
# 					atalanta
#
#
#
#
# 					genoa
#
#
#
#
# 						0-1
#
#
#
#
# 						0-2
#
#
#
#
#
#
# 					cagliari
#
#
#
#
# 					siena
#
#
#
#
# 						1-3
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					chievo
#
#
#
#
# 					lazio
#
#
#
#
# 						1-2
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					fiorentina
#
#
#
#
# 					palermo
#
#
#
#
# 						1-0
#
#
#
#
# 						0-3
#
#
#
#
#
#
# 					napoli
#
#
#
#
# 					livorno
#
#
#
#
# 						3-1
#
#
#
#
# 						2-0
#
#
#
#
#
#
# 					parma
#
#
#
#
# 					catania
#
#
#
#
# 						2-1
#
#
#
#
# 						0-3
#
#
#
#
#
#
# 					sampdoria
#
#
#
#
# 					udinese
#
#
#
#
# 						3-1
#
#
#
#
# 						3-2
#
#
#
#
#
#
#
#
#
#
#  3  Giornata
# Andata
# 		12,
# 		13-set
#
# Ritorno
# 		30,10-feb
#
#
#
#
#
# 					livorno
#
#
#
#
# 					milan
#
#
#
#
# 						0-0
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					lazio
#
#
#
#
# 					juventus
#
#
#
#
# 						0-2
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					atalanta
#
#
#
#
# 					sampdoria
#
#
#
#
# 						0-1
#
#
#
#
# 						0-2
#
#
#
#
#
#
# 					bologna
#
#
#
#
# 					chievo
#
#
#
#
# 						0-2
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					fiorentina
#
#
#
#
# 					cagliari
#
#
#
#
# 						1-0
#
#
#
#
# 						2-2
#
#
#
#
#
#
# 					inter
#
#
#
#
# 					parma
#
#
#
#
# 						2-0
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					palermo
#
#
#
#
# 					bari
#
#
#
#
# 						1-1
#
#
#
#
# 						2-4
#
#
#
#
#
#
# 					siena
#
#
#
#
# 					roma
#
#
#
#
# 						1-2
#
#
#
#
# 						1-2
#
#
#
#
#
#
# 					udinese
#
#
#
#
# 					catania
#
#
#
#
# 						4-2
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					genoa
#
#
#
#
# 					napoli
#
#
#
#
# 						4-1
#
#
#
#
# 						0-0
#
#
#
#
#
#
#
#
#
#
#  4  Giornata
# Andata
# 		19,
# 		20-set
#
# Ritorno
# 		06,07-feb
#
#
#
#
#
# 					napoli
#
#
#
#
# 					udinese
#
#
#
#
# 						0-0
#
#
#
#
# 						1-3
#
#
#
#
#
#
# 					juventus
#
#
#
#
# 					livorno
#
#
#
#
# 						2-0
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					bari
#
#
#
#
# 					atalanta
#
#
#
#
# 						4-1
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					cagliari
#
#
#
#
# 					inter
#
#
#
#
# 						1-2
#
#
#
#
# 						0-3
#
#
#
#
#
#
# 					catania
#
#
#
#
# 					lazio
#
#
#
#
# 						1-1
#
#
#
#
# 						1-0
#
#
#
#
#
#
# 					chievo
#
#
#
#
# 					genoa
#
#
#
#
# 						3-1
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					milan
#
#
#
#
# 					bologna
#
#
#
#
# 						1-0
#
#
#
#
# 						0-0
#
#
#
#
#
#
# 					parma
#
#
#
#
# 					palermo
#
#
#
#
# 						1-0
#
#
#
#
# 						1-2
#
#
#
#
#
#
# 					sampdoria
#
#
#
#
# 					siena
#
#
#
#
# 						4-1
#
#
#
#
# 						2-1
#
#
#
#
#
#
# 					roma
#
#
#
#
# 					fiorentina
#
#
#
#
# 						3-1
#
#
#
#
# 						1-0
#
#
#
#
#
#
#
#
#
#
#  5  Giornata
# Andata
# 		23,
# 		24-set
#
# Ritorno
# 		12,14-feb
#
#
#
#
#
# 					atalanta
#
#
#
#
# 					catania
#
#
#
#
# 						0-0
#
#
#
#
# 						0-0
#
#
#
#
#
#
# 					bari
#
#
#
#
# 					cagliari
#
#
#
#
# 						0-1
#
#
#
#
# 						1-3
#
#
#
#
#
#
# 					bologna
#
#
#
#
# 					livorno
#
#
#
#
# 						2-0
#
#
#
#
# 						1-0
#
#
#
#
#
#
# 					fiorentina
#
#
#
#
# 					sampdoria
#
#
#
#
# 						2-0
#
#
#
#
# 						0-2
#
#
#
#
#
#
# 					inter
#
#
#
#
# 					napoli
#
#
#
#
# 						3-1
#
#
#
#
# 						0-0
#
#
#
#
#
#
# 					lazio
#
#
#
#
# 					parma
#
#
#
#
# 						1-2
#
#
#
#
# 						2-0
#
#
#
#
#
#
# 					palermo
#
#
#
#
# 					roma
#
#
#
#
# 						3-3
#
#
#
#
# 						1-4
#
#
#
#
#
#
# 					siena
#
#
#
#
# 					chievo
#
#
#
#
# 						0-0
#
#
#
#
# 						1-0
#
#
#
#
#
#
# 					udinese
#
#
#
#
# 					milan
#
#
#
#
# 						1-0
#
#
#
#
# 						2-3
#
#
#
#
#
#
# 					genoa
#
#
#
#
# 					juventus
#
#
#
#
# 						2-2
#
#
#
#
# 						2-3
#
#
#
#
#
#
#
#
#
#
#  6  Giornata
# Andata
# 		26,
# 		27-set
#
# Ritorno
# 		20,21-feb
#
#
#
#
#
# 					sampdoria
#
#
#
#
# 					inter
#
#
#
#
# 						1-0
#
#
#
#
# 						0-0
#
#
#
#
#
#
# 					livorno
#
#
#
#
# 					fiorentina
#
#
#
#
# 						0-1
#
#
#
#
# 						1-2
#
#
#
#
#
#
# 					catania
#
#
#
#
# 					roma
#
#
#
#
# 						1-1
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					chievo
#
#
#
#
# 					atalanta
#
#
#
#
# 						1-1
#
#
#
#
# 						1-0
#
#
#
#
#
#
# 					juventus
#
#
#
#
# 					bologna
#
#
#
#
# 						1-1
#
#
#
#
# 						2-1
#
#
#
#
#
#
# 					lazio
#
#
#
#
# 					palermo
#
#
#
#
# 						1-1
#
#
#
#
# 						1-3
#
#
#
#
#
#
# 					napoli
#
#
#
#
# 					siena
#
#
#
#
# 						2-1
#
#
#
#
# 						0-0
#
#
#
#
#
#
# 					parma
#
#
#
#
# 					cagliari
#
#
#
#
# 						0-2
#
#
#
#
# 						0-2
#
#
#
#
#
#
# 					udinese
#
#
#
#
# 					genoa
#
#
#
#
# 						2-0
#
#
#
#
# 						0-3
#
#
#
#
#
#
# 					milan
#
#
#
#
# 					bari
#
#
#
#
# 						0-0
#
#
#
#
# 						2-0
#
#
#
#
#
#
#
#
#
#
#  7  Giornata
# Andata
# 		03,
# 		04-ott
#
# Ritorno
# 		27,28-feb
#
#
#
#
#
# 					bari
#
#
#
#
# 					catania
#
#
#
#
# 						0-0
#
#
#
#
# 						0-4
#
#
#
#
#
#
# 					inter
#
#
#
#
# 					udinese
#
#
#
#
# 						2-1
#
#
#
#
# 						3-2
#
#
#
#
#
#
# 					atalanta
#
#
#
#
# 					milan
#
#
#
#
# 						1-1
#
#
#
#
# 						1-3
#
#
#
#
#
#
# 					bologna
#
#
#
#
# 					genoa
#
#
#
#
# 						1-3
#
#
#
#
# 						4-3
#
#
#
#
#
#
# 					cagliari
#
#
#
#
# 					chievo
#
#
#
#
# 						1-2
#
#
#
#
# 						1-2
#
#
#
#
#
#
# 					fiorentina
#
#
#
#
# 					lazio
#
#
#
#
# 						0-0
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					roma
#
#
#
#
# 					napoli
#
#
#
#
# 						2-1
#
#
#
#
# 						2-2
#
#
#
#
#
#
# 					sampdoria
#
#
#
#
# 					parma
#
#
#
#
# 						1-1
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					siena
#
#
#
#
# 					livorno
#
#
#
#
# 						0-0
#
#
#
#
# 						2-1
#
#
#
#
#
#
# 					palermo
#
#
#
#
# 					juventus
#
#
#
#
# 						2-0
#
#
#
#
# 						2-0
#
#
#
#
#
#
#
#
#
#
#  8  Giornata
# Andata
# 		17,
# 		18-ott
#
# Ritorno
# 		06,07-mar
#
#
#
#
#
# 					juventus
#
#
#
#
# 					fiorentina
#
#
#
#
# 						1-1
#
#
#
#
# 						2-1
#
#
#
#
#
#
# 					genoa
#
#
#
#
# 					inter
#
#
#
#
# 						0-5
#
#
#
#
# 						0-0
#
#
#
#
#
#
# 					catania
#
#
#
#
# 					cagliari
#
#
#
#
# 						2-1
#
#
#
#
# 						2-2
#
#
#
#
#
#
# 					chievo
#
#
#
#
# 					bari
#
#
#
#
# 						1-2
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					lazio
#
#
#
#
# 					sampdoria
#
#
#
#
# 						1-1
#
#
#
#
# 						1-2
#
#
#
#
#
#
# 					livorno
#
#
#
#
# 					palermo
#
#
#
#
# 						1-2
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					napoli
#
#
#
#
# 					bologna
#
#
#
#
# 						2-1
#
#
#
#
# 						1-2
#
#
#
#
#
#
# 					parma
#
#
#
#
# 					siena
#
#
#
#
# 						1-0
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					udinese
#
#
#
#
# 					atalanta
#
#
#
#
# 						1-3
#
#
#
#
# 						0-0
#
#
#
#
#
#
# 					milan
#
#
#
#
# 					roma
#
#
#
#
# 						2-1
#
#
#
#
# 						0-0
#
#
#
#
#
#
#
#
#
#
#  9  Giornata
# Andata
# 		24,
# 		25-ott
#
# Ritorno
# 		12,14-mar
#
#
#
#
#
# 					sampdoria
#
#
#
#
# 					bologna
#
#
#
#
# 						4-1
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					inter
#
#
#
#
# 					catania
#
#
#
#
# 						2-1
#
#
#
#
# 						1-3
#
#
#
#
#
#
# 					atalanta
#
#
#
#
# 					parma
#
#
#
#
# 						3-1
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					bari
#
#
#
#
# 					lazio
#
#
#
#
# 						2-0
#
#
#
#
# 						2-0
#
#
#
#
#
#
# 					cagliari
#
#
#
#
# 					genoa
#
#
#
#
# 						3-2
#
#
#
#
# 						3-5
#
#
#
#
#
#
# 					fiorentina
#
#
#
#
# 					napoli
#
#
#
#
# 						0-1
#
#
#
#
# 						3-1
#
#
#
#
#
#
# 					palermo
#
#
#
#
# 					udinese
#
#
#
#
# 						1-0
#
#
#
#
# 						2-3
#
#
#
#
#
#
# 					roma
#
#
#
#
# 					livorno
#
#
#
#
# 						0-1
#
#
#
#
# 						3-3
#
#
#
#
#
#
# 					siena
#
#
#
#
# 					juventus
#
#
#
#
# 						0-1
#
#
#
#
# 						3-3
#
#
#
#
#
#
# 					chievo
#
#
#
#
# 					milan
#
#
#
#
# 						1-2
#
#
#
#
# 						0-1
#
#
#
#
#
#
#
#
#
#
#  10  Giornata
# Andata
# 		28,
# 		29-ott
#
# Ritorno
# 		20,21-mar
#
#
#
#
#
# 					bologna
#
#
#
#
# 					siena
#
#
#
#
# 						2-1
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					catania
#
#
#
#
# 					chievo
#
#
#
#
# 						1-2
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					genoa
#
#
#
#
# 					fiorentina
#
#
#
#
# 						2-1
#
#
#
#
# 						0-3
#
#
#
#
#
#
# 					juventus
#
#
#
#
# 					sampdoria
#
#
#
#
# 						5-1
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					lazio
#
#
#
#
# 					cagliari
#
#
#
#
# 						0-1
#
#
#
#
# 						2-0
#
#
#
#
#
#
# 					livorno
#
#
#
#
# 					atalanta
#
#
#
#
# 						1-0
#
#
#
#
# 						0-3
#
#
#
#
#
#
# 					napoli
#
#
#
#
# 					milan
#
#
#
#
# 						2-2
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					parma
#
#
#
#
# 					bari
#
#
#
#
# 						2-0
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					udinese
#
#
#
#
# 					roma
#
#
#
#
# 						2-1
#
#
#
#
# 						2-4
#
#
#
#
#
#
# 					inter
#
#
#
#
# 					palermo
#
#
#
#
# 						5-3
#
#
#
#
# 						1-1
#
#
#
#
#
#
#
#
#
#
#  11  Giornata
# Andata
# 		31,
# 		01-nov
#
# Ritorno
# 		24,25-mar
#
#
#
#
#
# 					juventus
#
#
#
#
# 					napoli
#
#
#
#
# 						2-3
#
#
#
#
# 						1-3
#
#
#
#
#
#
# 					milan
#
#
#
#
# 					parma
#
#
#
#
# 						2-0
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					cagliari
#
#
#
#
# 					atalanta
#
#
#
#
# 						3-0
#
#
#
#
# 						1-3
#
#
#
#
#
#
# 					chievo
#
#
#
#
# 					udinese
#
#
#
#
# 						1-1
#
#
#
#
# 						0-0
#
#
#
#
#
#
# 					fiorentina
#
#
#
#
# 					catania
#
#
#
#
# 						3-1
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					livorno
#
#
#
#
# 					inter
#
#
#
#
# 						0-2
#
#
#
#
# 						0-3
#
#
#
#
#
#
# 					roma
#
#
#
#
# 					bologna
#
#
#
#
# 						2-1
#
#
#
#
# 						2-0
#
#
#
#
#
#
# 					sampdoria
#
#
#
#
# 					bari
#
#
#
#
# 						0-0
#
#
#
#
# 						1-2
#
#
#
#
#
#
# 					siena
#
#
#
#
# 					lazio
#
#
#
#
# 						1-1
#
#
#
#
# 						0-2
#
#
#
#
#
#
# 					palermo
#
#
#
#
# 					genoa
#
#
#
#
# 						0-0
#
#
#
#
# 						2-2
#
#
#
#
#
#
#
#
#
#
#  12  Giornata
# Andata
# 		07,
# 		08-nov
#
# Ritorno
# 		27,28-mar
#
#
#
#
#
# 					catania
#
#
#
#
# 					napoli
#
#
#
#
# 						0-0
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					atalanta
#
#
#
#
# 					juventus
#
#
#
#
# 						2-5
#
#
#
#
# 						1-2
#
#
#
#
#
#
# 					bari
#
#
#
#
# 					livorno
#
#
#
#
# 						1-0
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					bologna
#
#
#
#
# 					palermo
#
#
#
#
# 						3-1
#
#
#
#
# 						1-3
#
#
#
#
#
#
# 					cagliari
#
#
#
#
# 					sampdoria
#
#
#
#
# 						2-0
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					genoa
#
#
#
#
# 					siena
#
#
#
#
# 						4-2
#
#
#
#
# 						0-0
#
#
#
#
#
#
# 					lazio
#
#
#
#
# 					milan
#
#
#
#
# 						1-2
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					parma
#
#
#
#
# 					chievo
#
#
#
#
# 						2-0
#
#
#
#
# 						0-0
#
#
#
#
#
#
# 					udinese
#
#
#
#
# 					fiorentina
#
#
#
#
# 						0-1
#
#
#
#
# 						1-4
#
#
#
#
#
#
# 					inter
#
#
#
#
# 					roma
#
#
#
#
# 						1-1
#
#
#
#
# 						1-2
#
#
#
#
#
#
#
#
#
#
#  13  Giornata
# Andata
# 		21,
# 		22-nov
#
# Ritorno
# 03-apr
#
#
#
#
#
# 					bologna
#
#
#
#
# 					inter
#
#
#
#
# 						1-3
#
#
#
#
# 						0-3
#
#
#
#
#
#
# 					fiorentina
#
#
#
#
# 					parma
#
#
#
#
# 						2-3
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					livorno
#
#
#
#
# 					genoa
#
#
#
#
# 						2-1
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					milan
#
#
#
#
# 					cagliari
#
#
#
#
# 						4-3
#
#
#
#
# 						3-2
#
#
#
#
#
#
# 					napoli
#
#
#
#
# 					lazio
#
#
#
#
# 						0-0
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					palermo
#
#
#
#
# 					catania
#
#
#
#
# 						1-1
#
#
#
#
# 						0-2
#
#
#
#
#
#
# 					roma
#
#
#
#
# 					bari
#
#
#
#
# 						3-1
#
#
#
#
# 						1-0
#
#
#
#
#
#
# 					sampdoria
#
#
#
#
# 					chievo
#
#
#
#
# 						2-1
#
#
#
#
# 						2-1
#
#
#
#
#
#
# 					siena
#
#
#
#
# 					atalanta
#
#
#
#
# 						0-2
#
#
#
#
# 						0-2
#
#
#
#
#
#
# 					juventus
#
#
#
#
# 					udinese
#
#
#
#
# 						1-0
#
#
#
#
# 						0-3
#
#
#
#
#
#
#
#
#
#
#  14  Giornata
# Andata
# 		28,
# 		29-nov
#
# Ritorno
# 		10,11-apr
#
#
#
#
#
# 					udinese
#
#
#
#
# 					livorno
#
#
#
#
# 						2-0
#
#
#
#
# 						2-0
#
#
#
#
#
#
# 					genoa
#
#
#
#
# 					sampdoria
#
#
#
#
# 						3-0
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					atalanta
#
#
#
#
# 					roma
#
#
#
#
# 						1-2
#
#
#
#
# 						1-2
#
#
#
#
#
#
# 					bari
#
#
#
#
# 					siena
#
#
#
#
# 						2-1
#
#
#
#
# 						2-3
#
#
#
#
#
#
# 					cagliari
#
#
#
#
# 					juventus
#
#
#
#
# 						2-0
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					chievo
#
#
#
#
# 					palermo
#
#
#
#
# 						1-0
#
#
#
#
# 						1-3
#
#
#
#
#
#
# 					inter
#
#
#
#
# 					fiorentina
#
#
#
#
# 						1-0
#
#
#
#
# 						2-2
#
#
#
#
#
#
# 					lazio
#
#
#
#
# 					bologna
#
#
#
#
# 						0-0
#
#
#
#
# 						3-2
#
#
#
#
#
#
# 					parma
#
#
#
#
# 					napoli
#
#
#
#
# 						1-1
#
#
#
#
# 						3-2
#
#
#
#
#
#
# 					catania
#
#
#
#
# 					milan
#
#
#
#
# 						0-2
#
#
#
#
# 						2-2
#
#
#
#
#
#
#
#
#
#
#  15  Giornata
# Andata
# 		05,
# 		06-dic
#
# Ritorno
# 		16,18-apr
#
#
#
#
#
# 					milan
#
#
#
#
# 					sampdoria
#
#
#
#
# 						3-0
#
#
#
#
# 						1-2
#
#
#
#
#
#
# 					juventus
#
#
#
#
# 					inter
#
#
#
#
# 						2-1
#
#
#
#
# 						0-2
#
#
#
#
#
#
# 					bologna
#
#
#
#
# 					udinese
#
#
#
#
# 						2-1
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					fiorentina
#
#
#
#
# 					atalanta
#
#
#
#
# 						2-0
#
#
#
#
# 						1-2
#
#
#
#
#
#
# 					genoa
#
#
#
#
# 					parma
#
#
#
#
# 						2-2
#
#
#
#
# 						3-2
#
#
#
#
#
#
# 					livorno
#
#
#
#
# 					chievo
#
#
#
#
# 						0-2
#
#
#
#
# 						0-2
#
#
#
#
#
#
# 					napoli
#
#
#
#
# 					bari
#
#
#
#
# 						3-2
#
#
#
#
# 						2-1
#
#
#
#
#
#
# 					palermo
#
#
#
#
# 					cagliari
#
#
#
#
# 						2-1
#
#
#
#
# 						2-2
#
#
#
#
#
#
# 					siena
#
#
#
#
# 					catania
#
#
#
#
# 						3-2
#
#
#
#
# 						2-2
#
#
#
#
#
#
# 					roma
#
#
#
#
# 					lazio
#
#
#
#
# 						1-0
#
#
#
#
# 						2-1
#
#
#
#
#
#
#
#
#
#
#  16  Giornata
# Andata
# 		12,
# 		13-dic
#
# Ritorno
# 		24,25-apr
#
#
#
#
#
# 					cagliari
#
#
#
#
# 					napoli
#
#
#
#
# 						3-3
#
#
#
#
# 						0-0
#
#
#
#
#
#
# 					bari
#
#
#
#
# 					juventus
#
#
#
#
# 						3-1
#
#
#
#
# 						0-3
#
#
#
#
#
#
# 					atalanta
#
#
#
#
# 					inter
#
#
#
#
# 						1-1
#
#
#
#
# 						1-3
#
#
#
#
#
#
# 					catania
#
#
#
#
# 					livorno
#
#
#
#
# 						0-1
#
#
#
#
# 						1-3
#
#
#
#
#
#
# 					chievo
#
#
#
#
# 					fiorentina
#
#
#
#
# 						2-1
#
#
#
#
# 						2-0
#
#
#
#
#
#
# 					lazio
#
#
#
#
# 					genoa
#
#
#
#
# 						1-0
#
#
#
#
# 						2-1
#
#
#
#
#
#
# 					milan
#
#
#
#
# 					palermo
#
#
#
#
# 						0-2
#
#
#
#
# 						1-3
#
#
#
#
#
#
# 					parma
#
#
#
#
# 					bologna
#
#
#
#
# 						2-1
#
#
#
#
# 						1-2
#
#
#
#
#
#
# 					siena
#
#
#
#
# 					udinese
#
#
#
#
# 						2-1
#
#
#
#
# 						1-4
#
#
#
#
#
#
# 					sampdoria
#
#
#
#
# 					roma
#
#
#
#
# 						0-0
#
#
#
#
# 						2-1
#
#
#
#
#
#
#
#
#
#
#  17  Giornata
# Andata
# 		19,
# 		24-feb
#
# Ritorno
# 		01,02-mag
#
#
#
#
#
# 					juventus
#
#
#
#
# 					catania
#
#
#
#
# 						1-2
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					livorno
#
#
#
#
# 					sampdoria
#
#
#
#
# 						3-1
#
#
#
#
# 						0-2
#
#
#
#
#
#
# 					napoli
#
#
#
#
# 					chievo
#
#
#
#
# 						2-0
#
#
#
#
# 						2-1
#
#
#
#
#
#
# 					palermo
#
#
#
#
# 					siena
#
#
#
#
# 						1-0
#
#
#
#
# 						2-1
#
#
#
#
#
#
# 					roma
#
#
#
#
# 					parma
#
#
#
#
# 						2-0
#
#
#
#
# 						2-1
#
#
#
#
#
#
# 					inter
#
#
#
#
# 					lazio
#
#
#
#
# 						1-0
#
#
#
#
# 						2-0
#
#
#
#
#
#
# 					bologna
#
#
#
#
# 					atalanta
#
#
#
#
# 						2-2
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					genoa
#
#
#
#
# 					bari
#
#
#
#
# 						1-1
#
#
#
#
# 						0-3
#
#
#
#
#
#
# 					fiorentina
#
#
#
#
# 					milan
#
#
#
#
# 						1-2
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					udinese
#
#
#
#
# 					cagliari
#
#
#
#
# 						2-1
#
#
#
#
# 						2-2
#
#
#
#
#
#
#
#
#
#
#  18  Giornata
# Andata
# 		06-gen
#
# Ritorno
# 09-mag
#
#
#
#
#
# 					chievo
#
#
#
#
# 					inter
#
#
#
#
# 						0-1
#
#
#
#
# 						3-4
#
#
#
#
#
#
# 					atalanta
#
#
#
#
# 					napoli
#
#
#
#
# 						0-2
#
#
#
#
# 						0-2
#
#
#
#
#
#
# 					bari
#
#
#
#
# 					udinese
#
#
#
#
# 						2-0
#
#
#
#
# 						3-3
#
#
#
#
#
#
# 					cagliari
#
#
#
#
# 					roma
#
#
#
#
# 						2-2
#
#
#
#
# 						1-2
#
#
#
#
#
#
# 					catania
#
#
#
#
# 					bologna
#
#
#
#
# 						1-0
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					lazio
#
#
#
#
# 					livorno
#
#
#
#
# 						4-1
#
#
#
#
# 						2-1
#
#
#
#
#
#
# 					parma
#
#
#
#
# 					juventus
#
#
#
#
# 						1-2
#
#
#
#
# 						3-2
#
#
#
#
#
#
# 					sampdoria
#
#
#
#
# 					palermo
#
#
#
#
# 						1-1
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					siena
#
#
#
#
# 					fiorentina
#
#
#
#
# 						1-5
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					milan
#
#
#
#
# 					genoa
#
#
#
#
# 						5-2
#
#
#
#
# 						0-1
#
#
#
#
#
#
#
#
#
#
#  19  Giornata
# Andata
# 		09,
# 		10-gen
#
# Ritorno
# 		15,16-mag
#
#
#
#
#
# 					roma
#
#
#
#
# 					chievo
#
#
#
#
# 						1-0
#
#
#
#
# 						2-0
#
#
#
#
#
#
# 					inter
#
#
#
#
# 					siena
#
#
#
#
# 						4-3
#
#
#
#
# 						1-0
#
#
#
#
#
#
# 					bologna
#
#
#
#
# 					cagliari
#
#
#
#
# 						0-1
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					fiorentina
#
#
#
#
# 					bari
#
#
#
#
# 						2-1
#
#
#
#
# 						0-2
#
#
#
#
#
#
# 					genoa
#
#
#
#
# 					catania
#
#
#
#
# 						2-0
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					livorno
#
#
#
#
# 					parma
#
#
#
#
# 						2-1
#
#
#
#
# 						1-4
#
#
#
#
#
#
# 					napoli
#
#
#
#
# 					sampdoria
#
#
#
#
# 						1-0
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					palermo
#
#
#
#
# 					atalanta
#
#
#
#
# 						1-0
#
#
#
#
# 						2-1
#
#
#
#
#
#
# 					udinese
#
#
#
#
# 					lazio
#
#
#
#
# 						1-1
#
#
#
#
# 						1-3
#
#
#
#
#
#
# 					juventus
#
#
#
#
# 					milan
#
#
#
#
# 						0-3
#
#
#
#
# 						0-3
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!--// <![CDATA[
#      OA_show('1bacmkt1');
# // ]]> -->
#
# <!--// <![CDATA[
#   OA_show('1bacmkt2');
# // ]]> -->
#
# <!--// <![CDATA[
#   OA_show('1bacmkt3');
# // ]]> -->
#
# <!--// <![CDATA[
#   OA_show('1bacmkt4');
# // ]]> -->
#
#
#
#
#
#
#
#
#
#
#
#
# 	Poker
# 	GIOCA ONLINE NELLE POKER ROOM ITALIANE!
#
#
#
#
#
#
#
#
#
#
# Vivi tutte le emozioni di un vero tavolo da poker!
#
# Prova SISALPOKER.IT
#
#
#  Sei pronto per un vero torneo di poker?  GIOCA SU POKERSTARS.IT
#
#  La poker house dove trovare il tuo Gioco Digitale  Scopri subito GDpoker
#
#
#
#
#
#
#
# L�unica Poker Room che ti porta alle WSOP
#
# Gioca subito su www.peoplespoker.it
#
#
#
#
#
#
#
#
# L'adrenalina del Poker, la Sicurezza di Lottomatica.
# Gioca Ora!
#
#
#
#
# 		Home Poker
#
#
#
#
#   Pubblicit
#
#
# <!--// <![CDATA[
#      OA_show('GAZbac01');
# // ]]> -->
#
# <!--// <![CDATA[
#      OA_show('GAZbac02');
# // ]]> -->
#
# <!--// <![CDATA[
#      OA_show('GAZbac03');
# // ]]> -->
#
# <!--// <![CDATA[
#      OA_show('GAZbac04');
# // ]]> -->
#
# <!--// <![CDATA[
#      OA_show('GAZbac05');
# // ]]> -->
#
# <!--// <![CDATA[
#      OA_show('GAZbac06');
# // ]]> -->
#
# <!--// <![CDATA[
#      OA_show('GAZbac07');
# // ]]> -->
#
# <!--// <![CDATA[
#      OA_show('GAZbac08');
# // ]]> -->
#
# <!--// <![CDATA[
#      OA_show('GAZbac09');
# // ]]> -->
#
# <!--// <![CDATA[
#      OA_show('GAZbac10');
# // ]]> -->
#
#
#
#
#
#
#
#
#
# Altri caratteri
#
# 	Gazza Town
#
#
#
#
# 			Tifa ITALIA con i nostri grandi sconti! Fino a -50% su tutti i prodotti ufficiali della Nazionale! Scoprili!
#
#
# 		Acquista online
#
#
#
#
#
# 	Gazzetta store
#
#
#
#
# SOLDATINI D�ITALIA La storia italiana attraverso mitici soldatini dipinti a mano. Ogni gioved� in edicola solo con Gazzetta.
#
#
#
# TOURIST TROPHY 2011La collana ufficiale in DVD dedicata al TT 2011 e alle migliori gare stradali. Dal 5 luglio in edicola solo con Gazzetta.
#
#
#
#     FABRI FIBRA COLLECTION
# Tutti gli album del n.1 del rap italiano. Dall� 8 luglio in edicola CONTROCULTURA a soli 9,99 euro!
#
#
#
# 			Libreria Rizzoli.it
# 			SCOPRI IL DIGITALE!
# 			Scarica GRATIS Pinocchio di Collodi in versione eBook
#
#
#
#
#
# 		Acquista online, SPEDIZIONI GRATIS per l'acquisto di collane complete
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			Gazzetta.it
# 			Home |
# 			Calcio |
# 			Motori |
# 			Giro |
# 			Ciclismo |
# 			Basket |
# 			Altri Sport |
# 			Gazzetta TV |
# 			SportWeek |
# 			Blog |
# 			GazzaSpace |
# 			Magic |
# 			Giochi  Scommesse
#
#
#
# 			Fondazionecannavo.it |
#
# 			Rcs Mediagroup |
# 			Corriere.it |
# 			TrovoLavoro |
# 			Corriere Viaggi |
# 			Automobili.com |
# 			TrovoViaggi |
# 			Fueps |
# 			El Mundo |
# 			Rcs Mobile |
# 			RCS Sport |
# 			Dada.eu |
# 			Marca.com
#
#
# 			 Redazione |
#       Mappa |
# 			Scrivici |
#             Cookie policy e privacy
#
#
#
#
#
#
# 			Copyright 2014  RCS MediaGroup S.p.A. Tutti i diritti riservati | Per la pubblicit
#             RCS Mediagroup S.p.A. - Divisione Pubblicit
#             RCS MediaGroup S.p.A. Sede legale: via Angelo Rizzoli, 8 - 20132 Milano
#             |Codice Fiscale, Partita I.V.A. e Iscrizione al Registro delle Imprese di Milano n.12086540155
#             R.E.A. di Milano: 1524326 - Capitale sociale  475.134.602,10
#
#
#
#
#
#
#
# 		Hamburg Declaration
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# $('body#home #rightcol div.poker ul').shuffle();
#
#
#
#
#
#
# var cookie = $.cookie("rcsLogin");
#  if (cookie != null) {
#  $(".registrati_link").css("display","none");
#
#  }
#
#
#
#
# var addStyle = '<style type="text/css">.marca span.right {margin:-17px 10px 0 0;}</style>';
# var navAgent = navigator.userAgent.toString();
# if(navAgent.indexOf("Firefox")!=-1 && navAgent.indexOf("/3.0")!=-1){
# document.getElementsByTagName('head')[0].innerHTML += addStyle
# }
#
# if (browser_user_ag == "iPad") {
#
#
# if ( $(".medium-rectang").height()  < 10) {
# $('.medium-rectang"').css('display','none');
# }else{
# $('.square_ipad').css('display','none');
# }
#
# } else {
#
# }
#
#
#
#
#
#
#
#
#
#
#
#
#
#     $(document).ready(function() {
#
#       var mapPicture = $('#mapZoom');  // Must be already loaded or cached!
#       var altimetriaPicture = $('#altZoom');
#       var mapPictureWe = $('#mapZoomWe');
#       var altimetriaPictureWe = $('#altZoomWe');
#       var kmPicture = $('#kmZoom');
#       var cronoPicture = $('#cronoZoom');
#       var salitePicture = $('#saliteZoom');
#       var arrivoPicture = $("#arrivoZoom");
#       var partenzaPicture = $("#partenzaZoom");
#
#       if($(".bxslider-salite").length){
#         //setTimeout(function{
#           $(".bxslider-salite").bxSlider();
#           var salitePic = $('.saliteZoom');
#           zoomAndMove(salitePic, $('#zoom-in-salite'), $('#zoom-out-salite'));
#         //}, 100);
#       } else {
#           zoomAndMove(salitePicture, $('#zoom-in-salite'), $('#zoom-out-salite'));
#       }
#
#       zoomAndMove(mapPictureWe, $('#zoom-in-button-we'), $('#zoom-out-button-we'));
#       zoomAndMove(altimetriaPictureWe, $('#zoom-in-we'), $('#zoom-out-we'));
#       zoomAndMove(mapPicture, $('#zoom-in-button'), $('#zoom-out-button'));
#       zoomAndMove(altimetriaPicture, $('#zoom-in'), $('#zoom-out'));
#       zoomAndMove(kmPicture, $('#zoom-in-km'), $('#zoom-out-km'));
#       zoomAndMove(arrivoPicture, $('#zoom-in-arrivo'), $('#zoom-out-arrivo'));
#       zoomAndMove(partenzaPicture, $('#zoom-in-partenza'), $('#zoom-out-partenza'));
#
#       cronoPicture.guillotine({
#           eventOnChange: 'guillotinechange',
#           width: 800,
#           height: 400,
#           init: {scale: 0.2, angle: 0, x: 0, y: 0, w: 800, h: 300}
#       });
#
#       zoomAndMove(cronoPicture, $('#zoom-in-crono'), $('#zoom-out-crono'));
#
#     });
#
#     function zoomAndMove(picture, zoomInId, zoomOutId){
#       picture.guillotine({
#           eventOnChange: 'guillotinechange',
#           width: 800,
#           height: 400,
#           init: {scale: 0.2, x:0, y:150}
#       });
#
#       zoomInId.click(function(){ picture.guillotine('zoomIn'); });
#       zoomOutId.click(function(){ picture.guillotine('zoomOut'); });
#
#     }
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!--
#
# /************* DO NOT ALTER ANYTHING BELOW THIS LINE ! **************/
# var s_code=s.t();if(s_code)document.write(s_code)//-->
# <!--
# if(navigator.appVersion.indexOf('MSIE')>=0)document.write(unescape('%3C')+'\!-'+'-')
# //-->
#
#
#
#
#
#
#
#
#
#
# var _rsCI="rcs-it";	 /* client ID */
# var _rsCG="0";	 /* content group */
# var _rsDN="//secure-it.imrworldwide.com/";	 /* data node */
# var _rsCC=0;	 /* to turn on whether to check for existing cookie, 1=on */
# var _rsIP=1;	 /* to turn on 'invisible pixel' option, 1=on */

# %%
 for line in parser.text.split("\n"):
        print line
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# var perPath = '/ssi/2008/boxes/calcio/calendari/calendario_';
# var postPath = '.shtml';
# function stampaCal(url){
# 	url = url.replace('estero-','');
# 	window.open(perPath+url+postPath, "calWind",
# 	"toolbar=no,left=1,top=1,height=700,directories=no,location=no,status=no,statusbar=no,resizable=1,menubar=no,scrollbars=yes");
# }
#
#
#
#
#
#
#
#
# 		//variabile utilizzata nel meteo.js
# 		var pathImgMeteo = 'http://images2.gazzettaobjects.it/libs4/css/assets';
# 		//utilizzata per il menu di sportweek
# 		var selected = 'risultati';
#
# 		//ADV function
# 			function getSite() {
# 				return "gazzetta";
# 			};
#
# 		var temporeale_xml = "(none)";
#
# 		//CONTROLLO USERAGENT IPAD PER GESTIRE GLI ELEMENTI NON GESTITI
# 		var browser_user_ag = "";
# 		var useragent_check = navigator.userAgent;
# 		if(useragent_check.indexOf('iPad') > -1) browser_user_ag = "iPad";
#
# 		function popUpGallery_rel(url,type,strWidth,strHeight){
# 			var tools="";
# 			tools="resizable=0,toolbar=no,location=no,scrollbars=no,width="+strWidth+",height="+strHeight+",left=0,top=0";
# 			nuova_finestra=window.open(url,'fotogallery',tools);
# 			nuova_finestra.focus();
# 		}
#
# 		function openPopup_rel(element){
#
# 			var hr = $(element).attr("href");
#
# 			if(hr.indexOf("apri_popup_methode_mailto")==-1){
#
# 				if(($(element).attr("href")).indexOf("vuoto.shtml")>-1) {
# 					w = "750";
# 					h = "565";
# 				}
# 				else {
# 					if($.browser.msie && $.browser.version < 7){
# 						w = "600";
# 						h = "770";
# 					}
# 					else {
# 						w = "600";
# 						h = "750";
# 					}
# 				}
# 				popUpGallery_rel($(element).attr("href"),t,w,h);
# 			}
# 			return false;
# 		}
#
# 		Date.monthNames = ['mese','Gen', 'Feb', 'Mar', 'Apr', 'Mag', 'Giu', 'Lug', 'Ago', 'Set', 'Ott', 'Nov', 'Dic'];
# 		Date.dayNames = ['Dom', 'Lun', 'Mar', 'Mer', 'Gio', 'Ven', 'Sab'];
# 		Date.dayNamesLong = ['Domenica', 'Luned�', 'Marted�', 'Mercoled�', 'Gioved�', 'Venerd�', 'Sabato'];
# 		var server_date = '09-17-17-37-0-38-22-2017-16';
# 		var server_date_split = server_date.split('-');
#
# 		//MESE
# 		var server_m = (server_date_split[0]/1);
# 		var server_m_mm = server_date_split[0];
# 		//MESE TESTO
# 		var server_m_text = Date.monthNames[server_m];
#
# 		//GIORNO
# 		var server_d = (server_date_split[1]/1);
# 		var server_d_dd = server_date_split[1];
# 		//GIORNO TESTO
# 		var server_day_t = Date.dayNames[server_date_split[4]];
# 		var server_day_tt = Date.dayNamesLong[server_date_split[4]];
#
# 		//ANNO
# 		var server_y = server_date_split[2];
# 		var server_yyyy = server_date_split[7];
#
# 		//SETTIMANA
# 		var server_W = (server_date_split[3]/1)+1;
#
# 		if (server_W > 52) {
# 			var server_W = 1;
# 		}
#
# 		//NUMERO GIORNO SETTIMANA
# 		var server_day_of_week = server_date_split[4]/1;
# 		//SECONDI
# 		var server_secondi = server_date_split[8];
# 		//MINUTI
# 		var server_minute = server_date_split[5]/1;
# 		var server_minute_mm = server_date_split[5];
# 		//ORA
# 		var server_hour = server_date_split[6]/1;
# 		var server_hour_hh = server_date_split[6];
#
#
# 		function pickRandom(range) {
# 			if (Math.random) return Math.round(Math.random() * (range-1));
# 			else {
# 				var now = new Date();
# 				return (now.getTime() / 1000) % range;
# 			}
# 		}
#
#
#
#
#
#
#
#
#
#
#
#   	<!--
# 	///////////////// BT - Start /////////////////
# 	OAS_taxonomy = '';
# 	var pageUrlPath = window.location.href.replace(window.location.protocol + "//", "");
#
# 	pageUrlPath = pageUrlPath.replace(/%2F/g,"/");
#
# 	pageUrlPath = pageUrlPath.replace(/%3F/g,"/");
# 	pageUrlPath = pageUrlPath.replace(/\?/g,"/");
#
# 	pageUrlPath = pageUrlPath.replace(/%21/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/!/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%2A/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/\*/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%22/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/\"/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%27/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/'/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%28/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/\(/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%29/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/\)/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%3B/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/;/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%3A/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/\:/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%40/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/@/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%26/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/&/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%3D/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/=/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%2B/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/\+/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%24/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/\$/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%2C/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/,/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%23/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/#/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%5B/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/\[/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%5D/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/\]/g,"_");
#
# 	pageUrlPath = pageUrlPath.replace(/%20/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/ /g,"_");
#
# 	//Tenere la sostituzione del % come ultima istruzione
# 	pageUrlPath = pageUrlPath.replace(/%25/g,"_");
# 	pageUrlPath = pageUrlPath.replace(/\%/g,"_");
#
# 	//
# 	// Per disabilitare BT commentare la riga sottostante
# 	//
#
#
# 	-->
#
#
#
#
#
#
# 		// definizione variabili pagina e posizioni
#
#
# 			OAS_sitepage = 'gazzetta.it/calcio';
# 			OAS_listpos = 'Top,TopLeft,Frame1,Position1';
#
#
#   //end OAS Analytics
#
#
#
#
#
#
#
# 				var CookiePolicyAccepted = false;
#
# 					var _ricIsPresent = Boolean(document.cookie.match(/(?:^|;)\s?__ric=(.*?)(?:;|$)/));
# 					var _cpmt_xaValue = document.cookie.match(/(?:^|;)\s?cpmt_xa=(.*?)(?:;|$)/);
# 					var _cpmt_xaIsPresent = Boolean(_cpmt_xaValue && (_cpmt_xaValue[1].indexOf("5295") > -1));
# 					CookiePolicyAccepted = !navigator.cookieEnabled || _ricIsPresent || _cpmt_xaIsPresent;
#
#
#                 var _scriptSrc = "http://js.gazzettaobjects.it/includes2013/LIBS/js/mjx.js";
#                 var _mockScript = "http://js.gazzettaobjects.it/includes2013/LIBS/js/MJX_OFF/mjx.js";
#
#                 if(typeof CookiePolicyAccepted == "boolean" && CookiePolicyAccepted){
#                     document.write('<scr'+'ipt type="text/javascript" src="' + _scriptSrc + '"></sc'+'ript>');
#                 } else {
#                     document.write('<scr'+'ipt type="text/javascript" src="' + _mockScript + '"></sc'+'ript>');
#                 }
#
#
#
#
#
#
#
# function createEmbed(clipId, channelId, siteId)
# {
#   //console.log("clipId:"+clipId+", channelId: "+channelId+ ", siteId: "+siteId);
#
#
# 	var clsId = "clsid:D27CDB6E-AE6D-11cf-96B8-444553540000";
# 	var cdBase = "http://fpdownload.macromedia.com/pub/shockwave/cabs/flash/swflash.cab#version=8,0,0,0";
# 	var pId = "vxFlashPlayer4139";
# 	var width = "300";
# 	var height = "250";
# 	var movieParam = "http://publish.vx.roo.com/rcsgazzetta/mini/flashembed/";
# 	var allowScriptAccessParam = "always";
# 	var allowFullscreenParam = "true";
# 	var movieQuality = "high";
# 	var wmodeParam = "windowed";
#
# 	var scaleParam = "noScale";
# 	var embedType = "application/x-shockwave-flash";
# 	var embedSrc = "http://publish.vx.roo.com/rcsgazzetta/mini/flashembed/";
#
# 	var flashvarsParam = "vxBaseURL=http%3A//publish.vx.roo.com/rcsgazzetta/mini/&vxTemplate=http%3A//publish.vx.roo.com/rcsgazzetta/mini/Gazzetta_Miniplayer_Article.swf&vxEmbedMode=fullsize&vxSiteId="+siteId+"&vxChannel="+channelId+"&vxSearch=&vxClipId="+clipId+"&vxBitrate=&vxFormat=&vxServerBase=&vxIMU=&vxClickToPlay=&vxTint=&vxFullscreen=imuCompatibility&vxSecure=false&vxBD=&vxHBX=&vxExternalIMU=&vxRowCount=&vxStartMode=normal&vxCore=&vxPreviewId=&vxDebug=&vxFilmStrip=&vxDynChannel=&vxHBXClipIdVar=&vxHBXClientType=Flash Player&vxOriginChannel=";
#
#   document.write('<object classid="'+clsId+'" codebase="'+cdBase+'" id="'+pId+'" width="'+width+'" height="'+height+'"><param name="movie" value="'+movieParam+'" /><param name="allowScriptAccess" value="'+allowScriptAccessParam+'" /><param name="allowFullscreen" value="'+allowFullscreenParam+'" /><param name="quality" value="'+movieQuality+'" /><param name="scale" value="'+scaleParam+'" /><param name="wmode" value="'+wmodeParam+'" /><param name="flashvars" value="'+flashvarsParam+'"/><embed type="'+embedType+'" src="'+embedSrc+'" width="'+width+'" height="'+height+'" allowScriptAccess="'+allowScriptAccessParam+'" allowFullscreen="'+allowFullscreenParam+'" quality="'+movieQuality+'" scale="'+scaleParam+'" wmode="'+wmodeParam+'" flashvars="'+flashvarsParam+'"></embed></object>');
# }
#
#
#
#
# var disciplinaSelected;
# var currentDateCms;
#
# function CambiaDisciplina(disciplinaSelected) {
# 	$('.disciplina .selected, .scegli_disciplina .selected').removeClass('selected');
# 	$('.disciplina #' +disciplinaSelected).addClass('selected');
# 	$('.scegli_disciplina #' +disciplinaSelected).addClass('selected');
# }
# function CambiaData(currentDateCms) {
# 	$('.date .selected').removeClass('selected');
# 	$('.date .' +currentDate).addClass('selected');
#
# }
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!--// <![CDATA[
# var OA_zones = {
# 	'GAZbac01' : 220,
# 	'GAZbac02' : 221,
# 	'GAZbac03' : 222,
# 	'GAZbac04' : 223,
# 	'GAZbac05' : 224,
# 	'GAZbac06' : 225,
# 	'GAZbac07' : 226,
# 	'GAZbac08' : 227,
# 	'GAZbac09' : 228,
# 	'GAZbac10' : 229,
# 	'1bacmkt1': 365,
# 	'1bacmkt2': 366,
# 	'1bacmkt3': 367,
# 	'1bacmkt4': 368,
# 	'consigli1' : 380,
# 	'consigli2' : 381,
# 	'consigli3' : 382,
# 	'consigli4' : 383,
# 	'consigli5' : 384,
# 	'BoxPromoCALCIOGAZ01top' : 464,
# 	'BoxPromoCALCIOGAZ02bot' : 465,
# 	'Multibarmkt1' : 639,
# 	'MultibarDiretta1' : 640,
# 	'MultibarWidgetGoal':689
#
# };
# // ]]> -->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	Risultati e Classifiche - Calcio - Serie A - La Gazzetta dello Sport
#
#
#
#
#
#
#
#
#
#
#
# <!--
# OAS_AD('Position1');
# //-->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         mobile
#         gazzatown
#         sportlinx
#         forum
#
#
#
#
#
#
#
#
#   GAZZAGAME
#   I migliori giochi online, gratis!GIOCA SUBITO
#
#
#
#
#
#
#
#
#
#
#
#
# La Gazzetta dello Sport.it
#
#
#
#                         document.write(server_day_t+" "+server_d_dd+" "+server_m_text+" "+server_yyyy+", "+server_hour_hh+":"+server_minute_mm);
#                         RSS
#                         | VEDI TUTTE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     Temperatura  | Umidit
#
#
#
#                 Cambia localit
#
#
#
#
#
#
#
#
#
#
#
# 	  Bari
#
# 		Belluno
#
# 		Bergamo
#
# 		Bologna
#
# 		Cagliari
#
# 		Catania
#
#         Catanzaro
#
# 		Firenze
#
# 		Genova
#
# 		Lecce
#
# 		Livorno
#
# 		Milano
#
# 		Napoli
#
# 		Padova
#
# 		Palermo
#
# 		Parma
#
# 		Reggio Calabria
#
# 		Roma
#
# 		Rovigo
#
# 		Siena
#
# 		Torino
#
# 		Treviso
#
# 		Udine
#
# 		Verona
#
# 		Vicenza
#
#
#
#
#
# 	Conferma cambio localit
#
#
#
#
# 	Home
# 	Calcio
# 		Calciomercato
# 	ET-Calcio estero					Motori
#
#
#
#
#
# 	Tour
# 	Basket
#
#    Tennis
# 	Altri Sport
# 	GazzettaTV
# 	Blog
# 	GazzaSpace
# 		Magic
# 			Scommesse
# 				Gazzagame
#
#
#
#
# 	Home
# 	Tempo reale
# 	Serie A
# 	Nazionale
# 	Serie B
# 	Calciomercato
# 	Calcio Estero
# 	Champions League
# 	Europa League
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   <!--
#   OAS_AD('TopLeft');
#   //-->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Registrati
#
#
# 	Cerca
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# // Settaggi per stepCarousel
# stepcarousel.setup({
# 	galleryid: 'mygallery', //id of carousel DIV
# 	containerid: 'content_menu_eng', //id che contiene il galleryid
# 	beltclass: 'belt', //class of inner "belt" DIV containing all the panel DIVs
# 	panelclass: 'panel', //class of panel DIVs each holding content
# 	autostep: {enable:false, moveby:1, pause:3000},
# 	panelbehavior: {speed:200, wraparound:false, wrapbehavior:'slide', persist:false},
# 	defaultbuttons: {enable: true, moveby: 4, leftnav: ['http://www.gazzetta.it/libs/css/default_theme/assets/cms_barMenu/sxn_arrow.png', 166, 6], rightnav: ['http://www.gazzetta.it/libs/css/default_theme/assets/cms_barMenu/dxn_arrow.png', 190, 6]},
# 	statusvars: ['statusA', 'statusB', 'statusC'], //register 3 variables that contain current panel (start), current panel (last), and total panels
# 	contenttype: ['inline'], //content setting ['inline'] or ['ajax', 'path_to_external_file']
# 	oninit:function(){
# 			var posTab = queryString("pos");
# 			if (posTab == false) {
# 				posTab = 1;
# 			}
# 			stepcarousel.stepTo("mygallery", posTab);
# 			posTab = posTab-1;
# 			$(".belt li:eq("+posTab+")").find('a').addClass('active-tab-menu');
# 			 $(".belt div:eq("+posTab+")").find('a').addClass('active-tab-menu');
#
# 		}
# })
#
#
#
# 	RISULTATI E CLASSIFICHE
#
#
#
# 			SERIE A
# 			SERIE Bwin
# 			CHAMPIONS LEAGUE
# 			EUROPA LEAGUE
# 			COPPA ITALIA
# 			LIGA
# 			LIGUE 1
# 			BUNDESLIGA
# 			PREMIER LEAGUE
# 			SERIE PRO GIRONE 1 A
# 			SERIE PRO GIRONE 1 B
# 			SERIE PRO GIRONE 2 A
# 			SERIE PRO GIRONE 2 B
# 			SERIE PRO GIRONE 2 C
# 			SERIE D
# 			SOCCER 5
# 			SERIE A FEMMINILE
# 			MLS
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     RISULTATI E CLASSIFICHE
#
#     CALENDARIO
#
#     TUTTE LE SQUADRE
#
#     ALBO D'ORO
#
#
#
#
#
#
#
#
# 			SERIE A 2009/2010 Scarica e stampa il calendario completo in formato PDF
#
#
#
#
#  1  Giornata
# Andata
# 		22,
# 		23-ago
#
# Ritorno
# 		16,17-gen
#
#
#
#
#
# 					bologna
#
#
#
#
# 					fiorentina
#
#
#
#
# 						1-1
#
#
#
#
# 						2-1
#
#
#
#
#
#
# 					siena
#
#
#
#
# 					milan
#
#
#
#
# 						1-2
#
#
#
#
# 						0-4
#
#
#
#
#
#
# 					inter
#
#
#
#
# 					bari
#
#
#
#
# 						1-1
#
#
#
#
# 						2-2
#
#
#
#
#
#
# 					catania
#
#
#
#
# 					sampdoria
#
#
#
#
# 						1-2
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					genoa
#
#
#
#
# 					roma
#
#
#
#
# 						3-2
#
#
#
#
# 						0-3
#
#
#
#
#
#
# 					juventus
#
#
#
#
# 					chievo
#
#
#
#
# 						1-0
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					lazio
#
#
#
#
# 					atalanta
#
#
#
#
# 						1-0
#
#
#
#
# 						0-3
#
#
#
#
#
#
# 					livorno
#
#
#
#
# 					cagliari
#
#
#
#
# 						0-0
#
#
#
#
# 						0-3
#
#
#
#
#
#
# 					palermo
#
#
#
#
# 					napoli
#
#
#
#
# 						2-1
#
#
#
#
# 						0-0
#
#
#
#
#
#
# 					udinese
#
#
#
#
# 					parma
#
#
#
#
# 						2-2
#
#
#
#
# 						0-0
#
#
#
#
#
#
#
#
#
#
#  2  Giornata
# Andata
# 		29,
# 		30-ago
#
# Ritorno
# 		23,24-gen
#
#
#
#
#
# 					bari
#
#
#
#
# 					bologna
#
#
#
#
# 						0-0
#
#
#
#
# 						1-2
#
#
#
#
#
#
# 					milan
#
#
#
#
# 					inter
#
#
#
#
# 						0-4
#
#
#
#
# 						0-2
#
#
#
#
#
#
# 					roma
#
#
#
#
# 					juventus
#
#
#
#
# 						1-3
#
#
#
#
# 						2-1
#
#
#
#
#
#
# 					atalanta
#
#
#
#
# 					genoa
#
#
#
#
# 						0-1
#
#
#
#
# 						0-2
#
#
#
#
#
#
# 					cagliari
#
#
#
#
# 					siena
#
#
#
#
# 						1-3
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					chievo
#
#
#
#
# 					lazio
#
#
#
#
# 						1-2
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					fiorentina
#
#
#
#
# 					palermo
#
#
#
#
# 						1-0
#
#
#
#
# 						0-3
#
#
#
#
#
#
# 					napoli
#
#
#
#
# 					livorno
#
#
#
#
# 						3-1
#
#
#
#
# 						2-0
#
#
#
#
#
#
# 					parma
#
#
#
#
# 					catania
#
#
#
#
# 						2-1
#
#
#
#
# 						0-3
#
#
#
#
#
#
# 					sampdoria
#
#
#
#
# 					udinese
#
#
#
#
# 						3-1
#
#
#
#
# 						3-2
#
#
#
#
#
#
#
#
#
#
#  3  Giornata
# Andata
# 		12,
# 		13-set
#
# Ritorno
# 		30,10-feb
#
#
#
#
#
# 					livorno
#
#
#
#
# 					milan
#
#
#
#
# 						0-0
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					lazio
#
#
#
#
# 					juventus
#
#
#
#
# 						0-2
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					atalanta
#
#
#
#
# 					sampdoria
#
#
#
#
# 						0-1
#
#
#
#
# 						0-2
#
#
#
#
#
#
# 					bologna
#
#
#
#
# 					chievo
#
#
#
#
# 						0-2
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					fiorentina
#
#
#
#
# 					cagliari
#
#
#
#
# 						1-0
#
#
#
#
# 						2-2
#
#
#
#
#
#
# 					inter
#
#
#
#
# 					parma
#
#
#
#
# 						2-0
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					palermo
#
#
#
#
# 					bari
#
#
#
#
# 						1-1
#
#
#
#
# 						2-4
#
#
#
#
#
#
# 					siena
#
#
#
#
# 					roma
#
#
#
#
# 						1-2
#
#
#
#
# 						1-2
#
#
#
#
#
#
# 					udinese
#
#
#
#
# 					catania
#
#
#
#
# 						4-2
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					genoa
#
#
#
#
# 					napoli
#
#
#
#
# 						4-1
#
#
#
#
# 						0-0
#
#
#
#
#
#
#
#
#
#
#  4  Giornata
# Andata
# 		19,
# 		20-set
#
# Ritorno
# 		06,07-feb
#
#
#
#
#
# 					napoli
#
#
#
#
# 					udinese
#
#
#
#
# 						0-0
#
#
#
#
# 						1-3
#
#
#
#
#
#
# 					juventus
#
#
#
#
# 					livorno
#
#
#
#
# 						2-0
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					bari
#
#
#
#
# 					atalanta
#
#
#
#
# 						4-1
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					cagliari
#
#
#
#
# 					inter
#
#
#
#
# 						1-2
#
#
#
#
# 						0-3
#
#
#
#
#
#
# 					catania
#
#
#
#
# 					lazio
#
#
#
#
# 						1-1
#
#
#
#
# 						1-0
#
#
#
#
#
#
# 					chievo
#
#
#
#
# 					genoa
#
#
#
#
# 						3-1
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					milan
#
#
#
#
# 					bologna
#
#
#
#
# 						1-0
#
#
#
#
# 						0-0
#
#
#
#
#
#
# 					parma
#
#
#
#
# 					palermo
#
#
#
#
# 						1-0
#
#
#
#
# 						1-2
#
#
#
#
#
#
# 					sampdoria
#
#
#
#
# 					siena
#
#
#
#
# 						4-1
#
#
#
#
# 						2-1
#
#
#
#
#
#
# 					roma
#
#
#
#
# 					fiorentina
#
#
#
#
# 						3-1
#
#
#
#
# 						1-0
#
#
#
#
#
#
#
#
#
#
#  5  Giornata
# Andata
# 		23,
# 		24-set
#
# Ritorno
# 		12,14-feb
#
#
#
#
#
# 					atalanta
#
#
#
#
# 					catania
#
#
#
#
# 						0-0
#
#
#
#
# 						0-0
#
#
#
#
#
#
# 					bari
#
#
#
#
# 					cagliari
#
#
#
#
# 						0-1
#
#
#
#
# 						1-3
#
#
#
#
#
#
# 					bologna
#
#
#
#
# 					livorno
#
#
#
#
# 						2-0
#
#
#
#
# 						1-0
#
#
#
#
#
#
# 					fiorentina
#
#
#
#
# 					sampdoria
#
#
#
#
# 						2-0
#
#
#
#
# 						0-2
#
#
#
#
#
#
# 					inter
#
#
#
#
# 					napoli
#
#
#
#
# 						3-1
#
#
#
#
# 						0-0
#
#
#
#
#
#
# 					lazio
#
#
#
#
# 					parma
#
#
#
#
# 						1-2
#
#
#
#
# 						2-0
#
#
#
#
#
#
# 					palermo
#
#
#
#
# 					roma
#
#
#
#
# 						3-3
#
#
#
#
# 						1-4
#
#
#
#
#
#
# 					siena
#
#
#
#
# 					chievo
#
#
#
#
# 						0-0
#
#
#
#
# 						1-0
#
#
#
#
#
#
# 					udinese
#
#
#
#
# 					milan
#
#
#
#
# 						1-0
#
#
#
#
# 						2-3
#
#
#
#
#
#
# 					genoa
#
#
#
#
# 					juventus
#
#
#
#
# 						2-2
#
#
#
#
# 						2-3
#
#
#
#
#
#
#
#
#
#
#  6  Giornata
# Andata
# 		26,
# 		27-set
#
# Ritorno
# 		20,21-feb
#
#
#
#
#
# 					sampdoria
#
#
#
#
# 					inter
#
#
#
#
# 						1-0
#
#
#
#
# 						0-0
#
#
#
#
#
#
# 					livorno
#
#
#
#
# 					fiorentina
#
#
#
#
# 						0-1
#
#
#
#
# 						1-2
#
#
#
#
#
#
# 					catania
#
#
#
#
# 					roma
#
#
#
#
# 						1-1
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					chievo
#
#
#
#
# 					atalanta
#
#
#
#
# 						1-1
#
#
#
#
# 						1-0
#
#
#
#
#
#
# 					juventus
#
#
#
#
# 					bologna
#
#
#
#
# 						1-1
#
#
#
#
# 						2-1
#
#
#
#
#
#
# 					lazio
#
#
#
#
# 					palermo
#
#
#
#
# 						1-1
#
#
#
#
# 						1-3
#
#
#
#
#
#
# 					napoli
#
#
#
#
# 					siena
#
#
#
#
# 						2-1
#
#
#
#
# 						0-0
#
#
#
#
#
#
# 					parma
#
#
#
#
# 					cagliari
#
#
#
#
# 						0-2
#
#
#
#
# 						0-2
#
#
#
#
#
#
# 					udinese
#
#
#
#
# 					genoa
#
#
#
#
# 						2-0
#
#
#
#
# 						0-3
#
#
#
#
#
#
# 					milan
#
#
#
#
# 					bari
#
#
#
#
# 						0-0
#
#
#
#
# 						2-0
#
#
#
#
#
#
#
#
#
#
#  7  Giornata
# Andata
# 		03,
# 		04-ott
#
# Ritorno
# 		27,28-feb
#
#
#
#
#
# 					bari
#
#
#
#
# 					catania
#
#
#
#
# 						0-0
#
#
#
#
# 						0-4
#
#
#
#
#
#
# 					inter
#
#
#
#
# 					udinese
#
#
#
#
# 						2-1
#
#
#
#
# 						3-2
#
#
#
#
#
#
# 					atalanta
#
#
#
#
# 					milan
#
#
#
#
# 						1-1
#
#
#
#
# 						1-3
#
#
#
#
#
#
# 					bologna
#
#
#
#
# 					genoa
#
#
#
#
# 						1-3
#
#
#
#
# 						4-3
#
#
#
#
#
#
# 					cagliari
#
#
#
#
# 					chievo
#
#
#
#
# 						1-2
#
#
#
#
# 						1-2
#
#
#
#
#
#
# 					fiorentina
#
#
#
#
# 					lazio
#
#
#
#
# 						0-0
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					roma
#
#
#
#
# 					napoli
#
#
#
#
# 						2-1
#
#
#
#
# 						2-2
#
#
#
#
#
#
# 					sampdoria
#
#
#
#
# 					parma
#
#
#
#
# 						1-1
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					siena
#
#
#
#
# 					livorno
#
#
#
#
# 						0-0
#
#
#
#
# 						2-1
#
#
#
#
#
#
# 					palermo
#
#
#
#
# 					juventus
#
#
#
#
# 						2-0
#
#
#
#
# 						2-0
#
#
#
#
#
#
#
#
#
#
#  8  Giornata
# Andata
# 		17,
# 		18-ott
#
# Ritorno
# 		06,07-mar
#
#
#
#
#
# 					juventus
#
#
#
#
# 					fiorentina
#
#
#
#
# 						1-1
#
#
#
#
# 						2-1
#
#
#
#
#
#
# 					genoa
#
#
#
#
# 					inter
#
#
#
#
# 						0-5
#
#
#
#
# 						0-0
#
#
#
#
#
#
# 					catania
#
#
#
#
# 					cagliari
#
#
#
#
# 						2-1
#
#
#
#
# 						2-2
#
#
#
#
#
#
# 					chievo
#
#
#
#
# 					bari
#
#
#
#
# 						1-2
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					lazio
#
#
#
#
# 					sampdoria
#
#
#
#
# 						1-1
#
#
#
#
# 						1-2
#
#
#
#
#
#
# 					livorno
#
#
#
#
# 					palermo
#
#
#
#
# 						1-2
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					napoli
#
#
#
#
# 					bologna
#
#
#
#
# 						2-1
#
#
#
#
# 						1-2
#
#
#
#
#
#
# 					parma
#
#
#
#
# 					siena
#
#
#
#
# 						1-0
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					udinese
#
#
#
#
# 					atalanta
#
#
#
#
# 						1-3
#
#
#
#
# 						0-0
#
#
#
#
#
#
# 					milan
#
#
#
#
# 					roma
#
#
#
#
# 						2-1
#
#
#
#
# 						0-0
#
#
#
#
#
#
#
#
#
#
#  9  Giornata
# Andata
# 		24,
# 		25-ott
#
# Ritorno
# 		12,14-mar
#
#
#
#
#
# 					sampdoria
#
#
#
#
# 					bologna
#
#
#
#
# 						4-1
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					inter
#
#
#
#
# 					catania
#
#
#
#
# 						2-1
#
#
#
#
# 						1-3
#
#
#
#
#
#
# 					atalanta
#
#
#
#
# 					parma
#
#
#
#
# 						3-1
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					bari
#
#
#
#
# 					lazio
#
#
#
#
# 						2-0
#
#
#
#
# 						2-0
#
#
#
#
#
#
# 					cagliari
#
#
#
#
# 					genoa
#
#
#
#
# 						3-2
#
#
#
#
# 						3-5
#
#
#
#
#
#
# 					fiorentina
#
#
#
#
# 					napoli
#
#
#
#
# 						0-1
#
#
#
#
# 						3-1
#
#
#
#
#
#
# 					palermo
#
#
#
#
# 					udinese
#
#
#
#
# 						1-0
#
#
#
#
# 						2-3
#
#
#
#
#
#
# 					roma
#
#
#
#
# 					livorno
#
#
#
#
# 						0-1
#
#
#
#
# 						3-3
#
#
#
#
#
#
# 					siena
#
#
#
#
# 					juventus
#
#
#
#
# 						0-1
#
#
#
#
# 						3-3
#
#
#
#
#
#
# 					chievo
#
#
#
#
# 					milan
#
#
#
#
# 						1-2
#
#
#
#
# 						0-1
#
#
#
#
#
#
#
#
#
#
#  10  Giornata
# Andata
# 		28,
# 		29-ott
#
# Ritorno
# 		20,21-mar
#
#
#
#
#
# 					bologna
#
#
#
#
# 					siena
#
#
#
#
# 						2-1
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					catania
#
#
#
#
# 					chievo
#
#
#
#
# 						1-2
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					genoa
#
#
#
#
# 					fiorentina
#
#
#
#
# 						2-1
#
#
#
#
# 						0-3
#
#
#
#
#
#
# 					juventus
#
#
#
#
# 					sampdoria
#
#
#
#
# 						5-1
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					lazio
#
#
#
#
# 					cagliari
#
#
#
#
# 						0-1
#
#
#
#
# 						2-0
#
#
#
#
#
#
# 					livorno
#
#
#
#
# 					atalanta
#
#
#
#
# 						1-0
#
#
#
#
# 						0-3
#
#
#
#
#
#
# 					napoli
#
#
#
#
# 					milan
#
#
#
#
# 						2-2
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					parma
#
#
#
#
# 					bari
#
#
#
#
# 						2-0
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					udinese
#
#
#
#
# 					roma
#
#
#
#
# 						2-1
#
#
#
#
# 						2-4
#
#
#
#
#
#
# 					inter
#
#
#
#
# 					palermo
#
#
#
#
# 						5-3
#
#
#
#
# 						1-1
#
#
#
#
#
#
#
#
#
#
#  11  Giornata
# Andata
# 		31,
# 		01-nov
#
# Ritorno
# 		24,25-mar
#
#
#
#
#
# 					juventus
#
#
#
#
# 					napoli
#
#
#
#
# 						2-3
#
#
#
#
# 						1-3
#
#
#
#
#
#
# 					milan
#
#
#
#
# 					parma
#
#
#
#
# 						2-0
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					cagliari
#
#
#
#
# 					atalanta
#
#
#
#
# 						3-0
#
#
#
#
# 						1-3
#
#
#
#
#
#
# 					chievo
#
#
#
#
# 					udinese
#
#
#
#
# 						1-1
#
#
#
#
# 						0-0
#
#
#
#
#
#
# 					fiorentina
#
#
#
#
# 					catania
#
#
#
#
# 						3-1
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					livorno
#
#
#
#
# 					inter
#
#
#
#
# 						0-2
#
#
#
#
# 						0-3
#
#
#
#
#
#
# 					roma
#
#
#
#
# 					bologna
#
#
#
#
# 						2-1
#
#
#
#
# 						2-0
#
#
#
#
#
#
# 					sampdoria
#
#
#
#
# 					bari
#
#
#
#
# 						0-0
#
#
#
#
# 						1-2
#
#
#
#
#
#
# 					siena
#
#
#
#
# 					lazio
#
#
#
#
# 						1-1
#
#
#
#
# 						0-2
#
#
#
#
#
#
# 					palermo
#
#
#
#
# 					genoa
#
#
#
#
# 						0-0
#
#
#
#
# 						2-2
#
#
#
#
#
#
#
#
#
#
#  12  Giornata
# Andata
# 		07,
# 		08-nov
#
# Ritorno
# 		27,28-mar
#
#
#
#
#
# 					catania
#
#
#
#
# 					napoli
#
#
#
#
# 						0-0
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					atalanta
#
#
#
#
# 					juventus
#
#
#
#
# 						2-5
#
#
#
#
# 						1-2
#
#
#
#
#
#
# 					bari
#
#
#
#
# 					livorno
#
#
#
#
# 						1-0
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					bologna
#
#
#
#
# 					palermo
#
#
#
#
# 						3-1
#
#
#
#
# 						1-3
#
#
#
#
#
#
# 					cagliari
#
#
#
#
# 					sampdoria
#
#
#
#
# 						2-0
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					genoa
#
#
#
#
# 					siena
#
#
#
#
# 						4-2
#
#
#
#
# 						0-0
#
#
#
#
#
#
# 					lazio
#
#
#
#
# 					milan
#
#
#
#
# 						1-2
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					parma
#
#
#
#
# 					chievo
#
#
#
#
# 						2-0
#
#
#
#
# 						0-0
#
#
#
#
#
#
# 					udinese
#
#
#
#
# 					fiorentina
#
#
#
#
# 						0-1
#
#
#
#
# 						1-4
#
#
#
#
#
#
# 					inter
#
#
#
#
# 					roma
#
#
#
#
# 						1-1
#
#
#
#
# 						1-2
#
#
#
#
#
#
#
#
#
#
#  13  Giornata
# Andata
# 		21,
# 		22-nov
#
# Ritorno
# 03-apr
#
#
#
#
#
# 					bologna
#
#
#
#
# 					inter
#
#
#
#
# 						1-3
#
#
#
#
# 						0-3
#
#
#
#
#
#
# 					fiorentina
#
#
#
#
# 					parma
#
#
#
#
# 						2-3
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					livorno
#
#
#
#
# 					genoa
#
#
#
#
# 						2-1
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					milan
#
#
#
#
# 					cagliari
#
#
#
#
# 						4-3
#
#
#
#
# 						3-2
#
#
#
#
#
#
# 					napoli
#
#
#
#
# 					lazio
#
#
#
#
# 						0-0
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					palermo
#
#
#
#
# 					catania
#
#
#
#
# 						1-1
#
#
#
#
# 						0-2
#
#
#
#
#
#
# 					roma
#
#
#
#
# 					bari
#
#
#
#
# 						3-1
#
#
#
#
# 						1-0
#
#
#
#
#
#
# 					sampdoria
#
#
#
#
# 					chievo
#
#
#
#
# 						2-1
#
#
#
#
# 						2-1
#
#
#
#
#
#
# 					siena
#
#
#
#
# 					atalanta
#
#
#
#
# 						0-2
#
#
#
#
# 						0-2
#
#
#
#
#
#
# 					juventus
#
#
#
#
# 					udinese
#
#
#
#
# 						1-0
#
#
#
#
# 						0-3
#
#
#
#
#
#
#
#
#
#
#  14  Giornata
# Andata
# 		28,
# 		29-nov
#
# Ritorno
# 		10,11-apr
#
#
#
#
#
# 					udinese
#
#
#
#
# 					livorno
#
#
#
#
# 						2-0
#
#
#
#
# 						2-0
#
#
#
#
#
#
# 					genoa
#
#
#
#
# 					sampdoria
#
#
#
#
# 						3-0
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					atalanta
#
#
#
#
# 					roma
#
#
#
#
# 						1-2
#
#
#
#
# 						1-2
#
#
#
#
#
#
# 					bari
#
#
#
#
# 					siena
#
#
#
#
# 						2-1
#
#
#
#
# 						2-3
#
#
#
#
#
#
# 					cagliari
#
#
#
#
# 					juventus
#
#
#
#
# 						2-0
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					chievo
#
#
#
#
# 					palermo
#
#
#
#
# 						1-0
#
#
#
#
# 						1-3
#
#
#
#
#
#
# 					inter
#
#
#
#
# 					fiorentina
#
#
#
#
# 						1-0
#
#
#
#
# 						2-2
#
#
#
#
#
#
# 					lazio
#
#
#
#
# 					bologna
#
#
#
#
# 						0-0
#
#
#
#
# 						3-2
#
#
#
#
#
#
# 					parma
#
#
#
#
# 					napoli
#
#
#
#
# 						1-1
#
#
#
#
# 						3-2
#
#
#
#
#
#
# 					catania
#
#
#
#
# 					milan
#
#
#
#
# 						0-2
#
#
#
#
# 						2-2
#
#
#
#
#
#
#
#
#
#
#  15  Giornata
# Andata
# 		05,
# 		06-dic
#
# Ritorno
# 		16,18-apr
#
#
#
#
#
# 					milan
#
#
#
#
# 					sampdoria
#
#
#
#
# 						3-0
#
#
#
#
# 						1-2
#
#
#
#
#
#
# 					juventus
#
#
#
#
# 					inter
#
#
#
#
# 						2-1
#
#
#
#
# 						0-2
#
#
#
#
#
#
# 					bologna
#
#
#
#
# 					udinese
#
#
#
#
# 						2-1
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					fiorentina
#
#
#
#
# 					atalanta
#
#
#
#
# 						2-0
#
#
#
#
# 						1-2
#
#
#
#
#
#
# 					genoa
#
#
#
#
# 					parma
#
#
#
#
# 						2-2
#
#
#
#
# 						3-2
#
#
#
#
#
#
# 					livorno
#
#
#
#
# 					chievo
#
#
#
#
# 						0-2
#
#
#
#
# 						0-2
#
#
#
#
#
#
# 					napoli
#
#
#
#
# 					bari
#
#
#
#
# 						3-2
#
#
#
#
# 						2-1
#
#
#
#
#
#
# 					palermo
#
#
#
#
# 					cagliari
#
#
#
#
# 						2-1
#
#
#
#
# 						2-2
#
#
#
#
#
#
# 					siena
#
#
#
#
# 					catania
#
#
#
#
# 						3-2
#
#
#
#
# 						2-2
#
#
#
#
#
#
# 					roma
#
#
#
#
# 					lazio
#
#
#
#
# 						1-0
#
#
#
#
# 						2-1
#
#
#
#
#
#
#
#
#
#
#  16  Giornata
# Andata
# 		12,
# 		13-dic
#
# Ritorno
# 		24,25-apr
#
#
#
#
#
# 					cagliari
#
#
#
#
# 					napoli
#
#
#
#
# 						3-3
#
#
#
#
# 						0-0
#
#
#
#
#
#
# 					bari
#
#
#
#
# 					juventus
#
#
#
#
# 						3-1
#
#
#
#
# 						0-3
#
#
#
#
#
#
# 					atalanta
#
#
#
#
# 					inter
#
#
#
#
# 						1-1
#
#
#
#
# 						1-3
#
#
#
#
#
#
# 					catania
#
#
#
#
# 					livorno
#
#
#
#
# 						0-1
#
#
#
#
# 						1-3
#
#
#
#
#
#
# 					chievo
#
#
#
#
# 					fiorentina
#
#
#
#
# 						2-1
#
#
#
#
# 						2-0
#
#
#
#
#
#
# 					lazio
#
#
#
#
# 					genoa
#
#
#
#
# 						1-0
#
#
#
#
# 						2-1
#
#
#
#
#
#
# 					milan
#
#
#
#
# 					palermo
#
#
#
#
# 						0-2
#
#
#
#
# 						1-3
#
#
#
#
#
#
# 					parma
#
#
#
#
# 					bologna
#
#
#
#
# 						2-1
#
#
#
#
# 						1-2
#
#
#
#
#
#
# 					siena
#
#
#
#
# 					udinese
#
#
#
#
# 						2-1
#
#
#
#
# 						1-4
#
#
#
#
#
#
# 					sampdoria
#
#
#
#
# 					roma
#
#
#
#
# 						0-0
#
#
#
#
# 						2-1
#
#
#
#
#
#
#
#
#
#
#  17  Giornata
# Andata
# 		19,
# 		24-feb
#
# Ritorno
# 		01,02-mag
#
#
#
#
#
# 					juventus
#
#
#
#
# 					catania
#
#
#
#
# 						1-2
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					livorno
#
#
#
#
# 					sampdoria
#
#
#
#
# 						3-1
#
#
#
#
# 						0-2
#
#
#
#
#
#
# 					napoli
#
#
#
#
# 					chievo
#
#
#
#
# 						2-0
#
#
#
#
# 						2-1
#
#
#
#
#
#
# 					palermo
#
#
#
#
# 					siena
#
#
#
#
# 						1-0
#
#
#
#
# 						2-1
#
#
#
#
#
#
# 					roma
#
#
#
#
# 					parma
#
#
#
#
# 						2-0
#
#
#
#
# 						2-1
#
#
#
#
#
#
# 					inter
#
#
#
#
# 					lazio
#
#
#
#
# 						1-0
#
#
#
#
# 						2-0
#
#
#
#
#
#
# 					bologna
#
#
#
#
# 					atalanta
#
#
#
#
# 						2-2
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					genoa
#
#
#
#
# 					bari
#
#
#
#
# 						1-1
#
#
#
#
# 						0-3
#
#
#
#
#
#
# 					fiorentina
#
#
#
#
# 					milan
#
#
#
#
# 						1-2
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					udinese
#
#
#
#
# 					cagliari
#
#
#
#
# 						2-1
#
#
#
#
# 						2-2
#
#
#
#
#
#
#
#
#
#
#  18  Giornata
# Andata
# 		06-gen
#
# Ritorno
# 09-mag
#
#
#
#
#
# 					chievo
#
#
#
#
# 					inter
#
#
#
#
# 						0-1
#
#
#
#
# 						3-4
#
#
#
#
#
#
# 					atalanta
#
#
#
#
# 					napoli
#
#
#
#
# 						0-2
#
#
#
#
# 						0-2
#
#
#
#
#
#
# 					bari
#
#
#
#
# 					udinese
#
#
#
#
# 						2-0
#
#
#
#
# 						3-3
#
#
#
#
#
#
# 					cagliari
#
#
#
#
# 					roma
#
#
#
#
# 						2-2
#
#
#
#
# 						1-2
#
#
#
#
#
#
# 					catania
#
#
#
#
# 					bologna
#
#
#
#
# 						1-0
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					lazio
#
#
#
#
# 					livorno
#
#
#
#
# 						4-1
#
#
#
#
# 						2-1
#
#
#
#
#
#
# 					parma
#
#
#
#
# 					juventus
#
#
#
#
# 						1-2
#
#
#
#
# 						3-2
#
#
#
#
#
#
# 					sampdoria
#
#
#
#
# 					palermo
#
#
#
#
# 						1-1
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					siena
#
#
#
#
# 					fiorentina
#
#
#
#
# 						1-5
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					milan
#
#
#
#
# 					genoa
#
#
#
#
# 						5-2
#
#
#
#
# 						0-1
#
#
#
#
#
#
#
#
#
#
#  19  Giornata
# Andata
# 		09,
# 		10-gen
#
# Ritorno
# 		15,16-mag
#
#
#
#
#
# 					roma
#
#
#
#
# 					chievo
#
#
#
#
# 						1-0
#
#
#
#
# 						2-0
#
#
#
#
#
#
# 					inter
#
#
#
#
# 					siena
#
#
#
#
# 						4-3
#
#
#
#
# 						1-0
#
#
#
#
#
#
# 					bologna
#
#
#
#
# 					cagliari
#
#
#
#
# 						0-1
#
#
#
#
# 						1-1
#
#
#
#
#
#
# 					fiorentina
#
#
#
#
# 					bari
#
#
#
#
# 						2-1
#
#
#
#
# 						0-2
#
#
#
#
#
#
# 					genoa
#
#
#
#
# 					catania
#
#
#
#
# 						2-0
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					livorno
#
#
#
#
# 					parma
#
#
#
#
# 						2-1
#
#
#
#
# 						1-4
#
#
#
#
#
#
# 					napoli
#
#
#
#
# 					sampdoria
#
#
#
#
# 						1-0
#
#
#
#
# 						0-1
#
#
#
#
#
#
# 					palermo
#
#
#
#
# 					atalanta
#
#
#
#
# 						1-0
#
#
#
#
# 						2-1
#
#
#
#
#
#
# 					udinese
#
#
#
#
# 					lazio
#
#
#
#
# 						1-1
#
#
#
#
# 						1-3
#
#
#
#
#
#
# 					juventus
#
#
#
#
# 					milan
#
#
#
#
# 						0-3
#
#
#
#
# 						0-3
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!--// <![CDATA[
#      OA_show('1bacmkt1');
# // ]]> -->
#
# <!--// <![CDATA[
#   OA_show('1bacmkt2');
# // ]]> -->
#
# <!--// <![CDATA[
#   OA_show('1bacmkt3');
# // ]]> -->
#
# <!--// <![CDATA[
#   OA_show('1bacmkt4');
# // ]]> -->
#
#
#
#
#
#
#
#
#
#
#
#
# 	Poker
# 	GIOCA ONLINE NELLE POKER ROOM ITALIANE!
#
#
#
#
#
#
#
#
#
#
# Vivi tutte le emozioni di un vero tavolo da poker!
#
# Prova SISALPOKER.IT
#
#
#  Sei pronto per un vero torneo di poker?  GIOCA SU POKERSTARS.IT
#
#  La poker house dove trovare il tuo Gioco Digitale  Scopri subito GDpoker
#
#
#
#
#
#
#
# L�unica Poker Room che ti porta alle WSOP
#
# Gioca subito su www.peoplespoker.it
#
#
#
#
#
#
#
#
# L'adrenalina del Poker, la Sicurezza di Lottomatica.
# Gioca Ora!
#
#
#
#
# 		Home Poker
#
#
#
#
#   Pubblicit
#
#
# <!--// <![CDATA[
#      OA_show('GAZbac01');
# // ]]> -->
#
# <!--// <![CDATA[
#      OA_show('GAZbac02');
# // ]]> -->
#
# <!--// <![CDATA[
#      OA_show('GAZbac03');
# // ]]> -->
#
# <!--// <![CDATA[
#      OA_show('GAZbac04');
# // ]]> -->
#
# <!--// <![CDATA[
#      OA_show('GAZbac05');
# // ]]> -->
#
# <!--// <![CDATA[
#      OA_show('GAZbac06');
# // ]]> -->
#
# <!--// <![CDATA[
#      OA_show('GAZbac07');
# // ]]> -->
#
# <!--// <![CDATA[
#      OA_show('GAZbac08');
# // ]]> -->
#
# <!--// <![CDATA[
#      OA_show('GAZbac09');
# // ]]> -->
#
# <!--// <![CDATA[
#      OA_show('GAZbac10');
# // ]]> -->
#
#
#
#
#
#
#
#
#
# Altri caratteri
#
# 	Gazza Town
#
#
#
#
# 			Tifa ITALIA con i nostri grandi sconti! Fino a -50% su tutti i prodotti ufficiali della Nazionale! Scoprili!
#
#
# 		Acquista online
#
#
#
#
#
# 	Gazzetta store
#
#
#
#
# SOLDATINI D�ITALIA La storia italiana attraverso mitici soldatini dipinti a mano. Ogni gioved� in edicola solo con Gazzetta.
#
#
#
# TOURIST TROPHY 2011La collana ufficiale in DVD dedicata al TT 2011 e alle migliori gare stradali. Dal 5 luglio in edicola solo con Gazzetta.
#
#
#
#     FABRI FIBRA COLLECTION
# Tutti gli album del n.1 del rap italiano. Dall� 8 luglio in edicola CONTROCULTURA a soli 9,99 euro!
#
#
#
# 			Libreria Rizzoli.it
# 			SCOPRI IL DIGITALE!
# 			Scarica GRATIS Pinocchio di Collodi in versione eBook
#
#
#
#
#
# 		Acquista online, SPEDIZIONI GRATIS per l'acquisto di collane complete
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			Gazzetta.it
# 			Home |
# 			Calcio |
# 			Motori |
# 			Giro |
# 			Ciclismo |
# 			Basket |
# 			Altri Sport |
# 			Gazzetta TV |
# 			SportWeek |
# 			Blog |
# 			GazzaSpace |
# 			Magic |
# 			Giochi  Scommesse
#
#
#
# 			Fondazionecannavo.it |
#
# 			Rcs Mediagroup |
# 			Corriere.it |
# 			TrovoLavoro |
# 			Corriere Viaggi |
# 			Automobili.com |
# 			TrovoViaggi |
# 			Fueps |
# 			El Mundo |
# 			Rcs Mobile |
# 			RCS Sport |
# 			Dada.eu |
# 			Marca.com
#
#
# 			 Redazione |
#       Mappa |
# 			Scrivici |
#             Cookie policy e privacy
#
#
#
#
#
#
# 			Copyright 2014  RCS MediaGroup S.p.A. Tutti i diritti riservati | Per la pubblicit
#             RCS Mediagroup S.p.A. - Divisione Pubblicit
#             RCS MediaGroup S.p.A. Sede legale: via Angelo Rizzoli, 8 - 20132 Milano
#             |Codice Fiscale, Partita I.V.A. e Iscrizione al Registro delle Imprese di Milano n.12086540155
#             R.E.A. di Milano: 1524326 - Capitale sociale  475.134.602,10
#
#
#
#
#
#
#
# 		Hamburg Declaration
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# $('body#home #rightcol div.poker ul').shuffle();
#
#
#
#
#
#
# var cookie = $.cookie("rcsLogin");
#  if (cookie != null) {
#  $(".registrati_link").css("display","none");
#
#  }
#
#
#
#
# var addStyle = '<style type="text/css">.marca span.right {margin:-17px 10px 0 0;}</style>';
# var navAgent = navigator.userAgent.toString();
# if(navAgent.indexOf("Firefox")!=-1 && navAgent.indexOf("/3.0")!=-1){
# document.getElementsByTagName('head')[0].innerHTML += addStyle
# }
#
# if (browser_user_ag == "iPad") {
#
#
# if ( $(".medium-rectang").height()  < 10) {
# $('.medium-rectang"').css('display','none');
# }else{
# $('.square_ipad').css('display','none');
# }
#
# } else {
#
# }
#
#
#
#
#
#
#
#
#
#
#
#
#
#     $(document).ready(function() {
#
#       var mapPicture = $('#mapZoom');  // Must be already loaded or cached!
#       var altimetriaPicture = $('#altZoom');
#       var mapPictureWe = $('#mapZoomWe');
#       var altimetriaPictureWe = $('#altZoomWe');
#       var kmPicture = $('#kmZoom');
#       var cronoPicture = $('#cronoZoom');
#       var salitePicture = $('#saliteZoom');
#       var arrivoPicture = $("#arrivoZoom");
#       var partenzaPicture = $("#partenzaZoom");
#
#       if($(".bxslider-salite").length){
#         //setTimeout(function{
#           $(".bxslider-salite").bxSlider();
#           var salitePic = $('.saliteZoom');
#           zoomAndMove(salitePic, $('#zoom-in-salite'), $('#zoom-out-salite'));
#         //}, 100);
#       } else {
#           zoomAndMove(salitePicture, $('#zoom-in-salite'), $('#zoom-out-salite'));
#       }
#
#       zoomAndMove(mapPictureWe, $('#zoom-in-button-we'), $('#zoom-out-button-we'));
#       zoomAndMove(altimetriaPictureWe, $('#zoom-in-we'), $('#zoom-out-we'));
#       zoomAndMove(mapPicture, $('#zoom-in-button'), $('#zoom-out-button'));
#       zoomAndMove(altimetriaPicture, $('#zoom-in'), $('#zoom-out'));
#       zoomAndMove(kmPicture, $('#zoom-in-km'), $('#zoom-out-km'));
#       zoomAndMove(arrivoPicture, $('#zoom-in-arrivo'), $('#zoom-out-arrivo'));
#       zoomAndMove(partenzaPicture, $('#zoom-in-partenza'), $('#zoom-out-partenza'));
#
#       cronoPicture.guillotine({
#           eventOnChange: 'guillotinechange',
#           width: 800,
#           height: 400,
#           init: {scale: 0.2, angle: 0, x: 0, y: 0, w: 800, h: 300}
#       });
#
#       zoomAndMove(cronoPicture, $('#zoom-in-crono'), $('#zoom-out-crono'));
#
#     });
#
#     function zoomAndMove(picture, zoomInId, zoomOutId){
#       picture.guillotine({
#           eventOnChange: 'guillotinechange',
#           width: 800,
#           height: 400,
#           init: {scale: 0.2, x:0, y:150}
#       });
#
#       zoomInId.click(function(){ picture.guillotine('zoomIn'); });
#       zoomOutId.click(function(){ picture.guillotine('zoomOut'); });
#
#     }
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!--
#
# /************* DO NOT ALTER ANYTHING BELOW THIS LINE ! **************/
# var s_code=s.t();if(s_code)document.write(s_code)//-->
# <!--
# if(navigator.appVersion.indexOf('MSIE')>=0)document.write(unescape('%3C')+'\!-'+'-')
# //-->
#
#
#
#
#
#
#
#
#
#
# var _rsCI="rcs-it";	 /* client ID */
# var _rsCG="0";	 /* content group */
# var _rsDN="//secure-it.imrworldwide.com/";	 /* data node */
# var _rsCC=0;	 /* to turn on whether to check for existing cookie, 1=on */
# var _rsIP=1;	 /* to turn on 'invisible pixel' option, 1=on */
